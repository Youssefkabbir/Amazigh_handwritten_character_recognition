# %% [markdown]
# # The first step is to import the required Librairies

# %%
"""pandas is a Python package that provides fast, flexible, and expressive data structures
designed to make working with "relational" or "labeled" data both easy and intuitive."""
import pandas as pd
"""NumPy is a Python library used for working with arrays.
It also has functions for working in domain of linear algebra, fourier transform, and matrices."""
import numpy as np

"""Matplotlib is a comprehensive library for creating static, animated, and interactive
visualizations in Python. Matplotlib makes easy things easy and hard things possible."""
import  matplotlib.pyplot as plt 
"""OpenCV is the huge open-source library for the computer vision, machine learning, and image 
processing and now it plays a major role in real-time operation which is very important
in today’s systems"""
import cv2
"""This module provides a portable way of using operating system dependent functionality. If you
just want to read or write a file see open(), if you want to manipulate paths, see the os.path 
module, and if you want to read all the lines in all the files on the command line see the 
fileinput module"""
import os
"""The Python Imaging Library adds image processing capabilities to your Python interpreter.
This library provides extensive file format support, an efficient internal representation, 
and fairly powerful image processing capabilities."""
from PIL import Image
"""scikit-learn is a Python module for machine learning built on top of SciPy and is distributed
under the 3-Clause BSD license."""
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import itertools
"""Tensorflow is one of the most-used deep-learning frameworks. It’s arguably the most popular
machine learning platform on the web, with a broad range of users from those just starting out, 
to people looking for an edge in their careers and businesses. """
import tensorflow as tf 
from tensorflow.keras.utils import  to_categorical
from tensorflow.keras.models import Sequential ,load_model
from tensorflow.keras.layers import Conv2D,MaxPool2D,Dense ,Flatten,Dropout
print('the cell was executed without errors')
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16 
from tensorflow.keras.applications.vgg19 import   VGG19
#from keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras import layers, models, Model, optimizers
from tensorflow.keras.optimizers import RMSprop,SGD,Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
# Out:
# the cell was executed without errors

# %% [markdown]
# # We are going to load our Dataset

# %%
Path_Data=r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\data\processed"
Data=pd.read_csv(os.path.join(Path_Data,"Data.csv"))

# %%
data_path=r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\data\raw\AMHCD_64"
categories=os.listdir(data_path)
print(categories)
number_Classes=len(categories)
print(number_Classes)
# Out:
# ['ya', 'yab', 'yach', 'yad', 'yadd', 'yae', 'yaf', 'yag', 'yagh', 'yagw', 'yah', 'yahh', 'yaj', 'yak', 'yakw', 'yal', 'yam', 'yan', 'yaq', 'yar', 'yarr', 'yas', 'yass', 'yat', 'yatt', 'yaw', 'yax', 'yay', 'yaz', 'yazz', 'yey', 'yi', 'yu']
# 33

# %%
"""
Data['Classes']=Data['Classes'].astype(str)

dummies =pd.get_dummies(Data['Classes'],drop_first=True).astype(int)
Examples=Data['Path']

merged = pd.concat([Examples,dummies],axis=1)
labels=('ya', 'yab', 'yach', 'yad', 'yadd', 'yae', 'yaf', 'yag', 'yagh', 'yagw', 'yah', 'yahh', 'yaj', 'yak', 'yakw'
        , 'yal', 'yam', 'yan', 'yaq', 'yar', 'yarr', 'yas', 'yass', 'yat', 'yatt', 'yaw', 'yax', 'yay', 'yaz', 'yazz'
        , 'yey', 'yi', 'yu')"""
# Out:
# "\nData['Classes']=Data['Classes'].astype(str)\n\ndummies =pd.get_dummies(Data['Classes'],drop_first=True).astype(int)\nExamples=Data['Path']\n\nmerged = pd.concat([Examples,dummies],axis=1)\nlabels=('ya', 'yab', 'yach', 'yad', 'yadd', 'yae', 'yaf', 'yag', 'yagh', 'yagw', 'yah', 'yahh', 'yaj', 'yak', 'yakw'\n        , 'yal', 'yam', 'yan', 'yaq', 'yar', 'yarr', 'yas', 'yass', 'yat', 'yatt', 'yaw', 'yax', 'yay', 'yaz', 'yazz'\n        , 'yey', 'yi', 'yu')"

# %%
from sklearn.model_selection import train_test_split
Train, Validation = train_test_split(Data, test_size = 0.3, random_state = 20)
train_datagen =  ImageDataGenerator(rescale=1. / 255,zoom_range=[0.7,1.0])

test_datagen = ImageDataGenerator( rescale=1./255)
print('the cell was executed without errors')
Train
# Out:
# the cell was executed without errors
#                                                     Path Classes
# 18692  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yat
# 22295  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yaz
# 18625  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yat
# 13017  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yam
# 8869   C:\Users\kabir\Desktop\Projects\Amazigh_handwr...    yahh
# ...                                                  ...     ...
# 14729  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yaq
# 23452  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yey
# 23775  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yey
# 4367   C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yae
# 15715  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...    yarr
#
# [18018 rows x 2 columns]

# %%
train_generator=train_datagen.flow_from_dataframe(
dataframe=Train,
directory=data_path,
x_col='Path',
y_col='Classes',
batch_size=32,
seed=42,
shuffle=False,
class_mode="categorical",
#class_mode="sparse",

target_size=(64,64))
# Out:
# Found 18018 validated image filenames belonging to 33 classes.

# %%
validation_generator=test_datagen.flow_from_dataframe(
dataframe=Validation,
directory=data_path,
x_col='Path',
y_col='Classes',
batch_size=32,
seed=42,
shuffle=False,
class_mode="categorical",

#class_mode="sparse",
target_size=(64,64))

print('the cell was executed without errors')
# Out:
# Found 7722 validated image filenames belonging to 33 classes.
# the cell was executed without errors

# %%
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=(64,64,3)))
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(rate=0.4))
model.add(Dense(33, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 60, 60, 32)        2432
#
#  conv2d_1 (Conv2D)           (None, 56, 56, 32)        25632
#
#  max_pooling2d (MaxPooling2D  (None, 28, 28, 32)       0
#  )
#
#  dropout (Dropout)           (None, 28, 28, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 26, 26, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 128)       0
#
#  flatten (Flatten)           (None, 18432)             0
#
#  dense (Dense)               (None, 256)               4718848
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 33)                8481
#
# =================================================================
# Total params: 4,847,745
# Trainable params: 4,847,745
# Non-trainable params: 0
# _________________________________________________________________

# %%
Path_Weights=r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\models\CNN"
#//checking checkpoint for selecting the best model for the emotion detection and save the best model with minimum validation loss having the name written on it in the current working folder
checkpoint = ModelCheckpoint(r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\models\CNN\Weights\Weight_CNN_2.h5",
                             monitor='val_loss',
                             mode='min',
                             save_best_only=True,
                             verbose=1)

#//reduce_lr will also monitor the validation loss 
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.1,
                              patience=3,
                              verbose=1,
                              min_lr=.000001)
#callb = [earlystop, checkpoint, reduce_lr]

call=[ checkpoint,reduce_lr]

# %%
adam = Adam(learning_rate=.0001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
s=train_generator.n/16
print(s)
# Out:
# 1126.125

# %%
batch_size=128
#//This last block of codes will train our codes with the given parameters where it will fit train generator for training epochs to 25, callbacks will call the earlystop, checkpoint and reduce_lr and validation data will be equal to validation generator which was created on the first execution 
history = model.fit_generator(generator=train_generator,steps_per_epoch=train_generator.n/batch_size, epochs=100
                              ,validation_data=validation_generator,validation_steps=validation_generator.n/batch_size)
# Out:
# C:\Users\kabir\AppData\Local\Temp\ipykernel_8940\582004472.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(generator=train_generator,steps_per_epoch=train_generator.n/batch_size, epochs=100
# Epoch 1/100
# 140/140 [==============================] - 62s 98ms/step - loss: 3.4934 - accuracy: 0.0471 - val_loss: 3.3605 - val_accuracy: 0.1260
# Epoch 2/100
# 140/140 [==============================] - 11s 78ms/step - loss: 2.2847 - accuracy: 0.3872 - val_loss: 1.1832 - val_accuracy: 0.6855
# Epoch 3/100
# 140/140 [==============================] - 11s 80ms/step - loss: 1.5060 - accuracy: 0.5851 - val_loss: 0.8930 - val_accuracy: 0.7551
# Epoch 4/100
# 140/140 [==============================] - 10s 72ms/step - loss: 1.2513 - accuracy: 0.6536 - val_loss: 0.7346 - val_accuracy: 0.8058
# Epoch 5/100
# 140/140 [==============================] - 11s 79ms/step - loss: 1.0862 - accuracy: 0.6922 - val_loss: 0.6100 - val_accuracy: 0.8304
# Epoch 6/100
# 140/140 [==============================] - 11s 79ms/step - loss: 0.9220 - accuracy: 0.7425 - val_loss: 0.4981 - val_accuracy: 0.8678
# Epoch 7/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.8197 - accuracy: 0.7595 - val_loss: 0.4075 - val_accuracy: 0.8909
# Epoch 8/100
# 140/140 [==============================] - 11s 80ms/step - loss: 0.7225 - accuracy: 0.7938 - val_loss: 0.3872 - val_accuracy: 0.8950
# Epoch 9/100
# 140/140 [==============================] - 12s 82ms/step - loss: 0.6502 - accuracy: 0.8090 - val_loss: 0.3132 - val_accuracy: 0.9165
# Epoch 10/100
# 140/140 [==============================] - 11s 80ms/step - loss: 0.6011 - accuracy: 0.8247 - val_loss: 0.2838 - val_accuracy: 0.9237
# Epoch 11/100
# 140/140 [==============================] - 8s 59ms/step - loss: 0.5598 - accuracy: 0.8375 - val_loss: 0.2862 - val_accuracy: 0.9303
# Epoch 12/100
# 140/140 [==============================] - 9s 67ms/step - loss: 0.5104 - accuracy: 0.8556 - val_loss: 0.2284 - val_accuracy: 0.9349
# Epoch 13/100
# 140/140 [==============================] - 9s 64ms/step - loss: 0.4670 - accuracy: 0.8615 - val_loss: 0.2083 - val_accuracy: 0.9447
# Epoch 14/100
# 140/140 [==============================] - 9s 67ms/step - loss: 0.4832 - accuracy: 0.8562 - val_loss: 0.2101 - val_accuracy: 0.9472
# Epoch 15/100
# 140/140 [==============================] - 8s 59ms/step - loss: 0.4382 - accuracy: 0.8648 - val_loss: 0.2056 - val_accuracy: 0.9457
# Epoch 16/100
# 140/140 [==============================] - 10s 68ms/step - loss: 0.4279 - accuracy: 0.8726 - val_loss: 0.1740 - val_accuracy: 0.9508
# Epoch 17/100
# 140/140 [==============================] - 12s 86ms/step - loss: 0.4246 - accuracy: 0.8779 - val_loss: 0.1794 - val_accuracy: 0.9513
# Epoch 18/100
# 140/140 [==============================] - 9s 67ms/step - loss: 0.3743 - accuracy: 0.8860 - val_loss: 0.1583 - val_accuracy: 0.9580
# Epoch 19/100
# 140/140 [==============================] - 10s 69ms/step - loss: 0.3800 - accuracy: 0.8811 - val_loss: 0.1582 - val_accuracy: 0.9575
# Epoch 20/100
# 140/140 [==============================] - 8s 57ms/step - loss: 0.3451 - accuracy: 0.8923 - val_loss: 0.1608 - val_accuracy: 0.9565
# Epoch 21/100
# 140/140 [==============================] - 9s 62ms/step - loss: 0.3655 - accuracy: 0.8894 - val_loss: 0.1489 - val_accuracy: 0.9559
# Epoch 22/100
# 140/140 [==============================] - 8s 58ms/step - loss: 0.3392 - accuracy: 0.8934 - val_loss: 0.1680 - val_accuracy: 0.9524
# Epoch 23/100
# 140/140 [==============================] - 8s 60ms/step - loss: 0.3290 - accuracy: 0.9003 - val_loss: 0.1485 - val_accuracy: 0.9565
# Epoch 24/100
# 140/140 [==============================] - 9s 63ms/step - loss: 0.3105 - accuracy: 0.9020 - val_loss: 0.1480 - val_accuracy: 0.9559
# Epoch 25/100
# 140/140 [==============================] - 8s 56ms/step - loss: 0.3131 - accuracy: 0.9038 - val_loss: 0.1307 - val_accuracy: 0.9626
# Epoch 26/100
# 140/140 [==============================] - 8s 59ms/step - loss: 0.2957 - accuracy: 0.9142 - val_loss: 0.1273 - val_accuracy: 0.9636
# Epoch 27/100
# 140/140 [==============================] - 9s 60ms/step - loss: 0.2720 - accuracy: 0.9160 - val_loss: 0.1311 - val_accuracy: 0.9565
# Epoch 28/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.2775 - accuracy: 0.9120 - val_loss: 0.1218 - val_accuracy: 0.9672
# Epoch 29/100
# 140/140 [==============================] - 9s 64ms/step - loss: 0.2563 - accuracy: 0.9184 - val_loss: 0.1258 - val_accuracy: 0.9631
# Epoch 30/100
# 140/140 [==============================] - 10s 70ms/step - loss: 0.2756 - accuracy: 0.9149 - val_loss: 0.1239 - val_accuracy: 0.9647
# Epoch 31/100
# 140/140 [==============================] - 10s 67ms/step - loss: 0.2493 - accuracy: 0.9218 - val_loss: 0.1154 - val_accuracy: 0.9647
# Epoch 32/100
# 140/140 [==============================] - 9s 62ms/step - loss: 0.2472 - accuracy: 0.9231 - val_loss: 0.1079 - val_accuracy: 0.9667
# Epoch 33/100
# 140/140 [==============================] - 10s 70ms/step - loss: 0.2686 - accuracy: 0.9132 - val_loss: 0.1099 - val_accuracy: 0.9647
# Epoch 34/100
# 140/140 [==============================] - 8s 56ms/step - loss: 0.2424 - accuracy: 0.9284 - val_loss: 0.1162 - val_accuracy: 0.9667
# Epoch 35/100
# 140/140 [==============================] - 9s 63ms/step - loss: 0.2452 - accuracy: 0.9189 - val_loss: 0.1119 - val_accuracy: 0.9672
# Epoch 36/100
# 140/140 [==============================] - 9s 62ms/step - loss: 0.2199 - accuracy: 0.9320 - val_loss: 0.1125 - val_accuracy: 0.9657
# Epoch 37/100
# 140/140 [==============================] - 9s 62ms/step - loss: 0.2380 - accuracy: 0.9255 - val_loss: 0.0941 - val_accuracy: 0.9708
# Epoch 38/100
# 140/140 [==============================] - 9s 64ms/step - loss: 0.2154 - accuracy: 0.9366 - val_loss: 0.1097 - val_accuracy: 0.9698
# Epoch 39/100
# 140/140 [==============================] - 9s 62ms/step - loss: 0.2313 - accuracy: 0.9284 - val_loss: 0.1068 - val_accuracy: 0.9698
# Epoch 40/100
# 140/140 [==============================] - 8s 56ms/step - loss: 0.2031 - accuracy: 0.9320 - val_loss: 0.1041 - val_accuracy: 0.9682
# Epoch 41/100
# 140/140 [==============================] - 9s 65ms/step - loss: 0.2122 - accuracy: 0.9304 - val_loss: 0.0875 - val_accuracy: 0.9744
# Epoch 42/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.1959 - accuracy: 0.9384 - val_loss: 0.0916 - val_accuracy: 0.9749
# Epoch 43/100
# 140/140 [==============================] - 9s 65ms/step - loss: 0.2045 - accuracy: 0.9337 - val_loss: 0.0894 - val_accuracy: 0.9744
# Epoch 44/100
# 140/140 [==============================] - 12s 85ms/step - loss: 0.2177 - accuracy: 0.9302 - val_loss: 0.1099 - val_accuracy: 0.9723
# Epoch 45/100
# 140/140 [==============================] - 13s 93ms/step - loss: 0.2050 - accuracy: 0.9342 - val_loss: 0.0934 - val_accuracy: 0.9744
# Epoch 46/100
# 140/140 [==============================] - 14s 97ms/step - loss: 0.2092 - accuracy: 0.9375 - val_loss: 0.0908 - val_accuracy: 0.9708
# Epoch 47/100
# 140/140 [==============================] - 9s 64ms/step - loss: 0.1990 - accuracy: 0.9384 - val_loss: 0.0952 - val_accuracy: 0.9693
# Epoch 48/100
# 140/140 [==============================] - 9s 62ms/step - loss: 0.1965 - accuracy: 0.9353 - val_loss: 0.0924 - val_accuracy: 0.9739
# Epoch 49/100
# 140/140 [==============================] - 8s 58ms/step - loss: 0.1897 - accuracy: 0.9364 - val_loss: 0.0873 - val_accuracy: 0.9759
# Epoch 50/100
# 140/140 [==============================] - 9s 62ms/step - loss: 0.1616 - accuracy: 0.9475 - val_loss: 0.0931 - val_accuracy: 0.9764
# Epoch 51/100
# 140/140 [==============================] - 9s 62ms/step - loss: 0.1896 - accuracy: 0.9415 - val_loss: 0.0918 - val_accuracy: 0.9754
# Epoch 52/100
# 140/140 [==============================] - 10s 74ms/step - loss: 0.1740 - accuracy: 0.9413 - val_loss: 0.0883 - val_accuracy: 0.9759
# Epoch 53/100
# 140/140 [==============================] - 10s 69ms/step - loss: 0.1780 - accuracy: 0.9419 - val_loss: 0.0806 - val_accuracy: 0.9775
# Epoch 54/100
# 140/140 [==============================] - 9s 66ms/step - loss: 0.1773 - accuracy: 0.9419 - val_loss: 0.0795 - val_accuracy: 0.9785
# Epoch 55/100
# 140/140 [==============================] - 11s 76ms/step - loss: 0.1460 - accuracy: 0.9519 - val_loss: 0.0728 - val_accuracy: 0.9764
# Epoch 56/100
# 140/140 [==============================] - 15s 104ms/step - loss: 0.1752 - accuracy: 0.9444 - val_loss: 0.0911 - val_accuracy: 0.9708
# Epoch 57/100
# 140/140 [==============================] - 13s 92ms/step - loss: 0.1555 - accuracy: 0.9488 - val_loss: 0.0896 - val_accuracy: 0.9728
# Epoch 58/100
# 140/140 [==============================] - 14s 98ms/step - loss: 0.1546 - accuracy: 0.9488 - val_loss: 0.0873 - val_accuracy: 0.9734
# Epoch 59/100
# 140/140 [==============================] - 10s 72ms/step - loss: 0.1564 - accuracy: 0.9486 - val_loss: 0.0904 - val_accuracy: 0.9749
# Epoch 60/100
# 140/140 [==============================] - 9s 63ms/step - loss: 0.1566 - accuracy: 0.9506 - val_loss: 0.0785 - val_accuracy: 0.9744
# Epoch 61/100
# 140/140 [==============================] - 9s 64ms/step - loss: 0.1368 - accuracy: 0.9572 - val_loss: 0.0867 - val_accuracy: 0.9790
# Epoch 62/100
# 140/140 [==============================] - 9s 63ms/step - loss: 0.1636 - accuracy: 0.9488 - val_loss: 0.0772 - val_accuracy: 0.9764
# Epoch 63/100
# 140/140 [==============================] - 10s 71ms/step - loss: 0.1663 - accuracy: 0.9426 - val_loss: 0.0811 - val_accuracy: 0.9744
# Epoch 64/100
# 140/140 [==============================] - 11s 77ms/step - loss: 0.1528 - accuracy: 0.9512 - val_loss: 0.0805 - val_accuracy: 0.9734
# Epoch 65/100
# 140/140 [==============================] - 12s 82ms/step - loss: 0.1502 - accuracy: 0.9521 - val_loss: 0.0837 - val_accuracy: 0.9749
# Epoch 66/100
# 140/140 [==============================] - 12s 88ms/step - loss: 0.1644 - accuracy: 0.9466 - val_loss: 0.0789 - val_accuracy: 0.9744
# Epoch 67/100
# 140/140 [==============================] - 10s 68ms/step - loss: 0.1402 - accuracy: 0.9532 - val_loss: 0.0956 - val_accuracy: 0.9728
# Epoch 68/100
# 140/140 [==============================] - 9s 61ms/step - loss: 0.1561 - accuracy: 0.9477 - val_loss: 0.0840 - val_accuracy: 0.9739
# Epoch 69/100
# 140/140 [==============================] - 9s 64ms/step - loss: 0.1414 - accuracy: 0.9528 - val_loss: 0.0769 - val_accuracy: 0.9744
# Epoch 70/100
# 140/140 [==============================] - 10s 72ms/step - loss: 0.1396 - accuracy: 0.9574 - val_loss: 0.0736 - val_accuracy: 0.9790
# Epoch 71/100
# 140/140 [==============================] - 9s 65ms/step - loss: 0.1319 - accuracy: 0.9563 - val_loss: 0.0732 - val_accuracy: 0.9821
# Epoch 72/100
# 140/140 [==============================] - 9s 66ms/step - loss: 0.1293 - accuracy: 0.9601 - val_loss: 0.0760 - val_accuracy: 0.9795
# Epoch 73/100
# 140/140 [==============================] - 10s 70ms/step - loss: 0.1249 - accuracy: 0.9603 - val_loss: 0.0797 - val_accuracy: 0.9785
# Epoch 74/100
# 140/140 [==============================] - 11s 77ms/step - loss: 0.1325 - accuracy: 0.9592 - val_loss: 0.0791 - val_accuracy: 0.9780
# Epoch 75/100
# 140/140 [==============================] - 11s 75ms/step - loss: 0.1277 - accuracy: 0.9599 - val_loss: 0.0791 - val_accuracy: 0.9764
# Epoch 76/100
# 140/140 [==============================] - 10s 69ms/step - loss: 0.1600 - accuracy: 0.9455 - val_loss: 0.0703 - val_accuracy: 0.9785
# Epoch 77/100
# 140/140 [==============================] - 10s 68ms/step - loss: 0.1161 - accuracy: 0.9612 - val_loss: 0.0660 - val_accuracy: 0.9816
# Epoch 78/100
# 140/140 [==============================] - 10s 72ms/step - loss: 0.1269 - accuracy: 0.9586 - val_loss: 0.0819 - val_accuracy: 0.9744
# Epoch 79/100
# 140/140 [==============================] - 10s 70ms/step - loss: 0.1280 - accuracy: 0.9598 - val_loss: 0.0739 - val_accuracy: 0.9775
# Epoch 80/100
# 140/140 [==============================] - 9s 65ms/step - loss: 0.1276 - accuracy: 0.9612 - val_loss: 0.0738 - val_accuracy: 0.9759
# Epoch 81/100
# 140/140 [==============================] - 10s 70ms/step - loss: 0.1282 - accuracy: 0.9555 - val_loss: 0.0734 - val_accuracy: 0.9775
# Epoch 82/100
# 140/140 [==============================] - 9s 60ms/step - loss: 0.1427 - accuracy: 0.9535 - val_loss: 0.0686 - val_accuracy: 0.9805
# Epoch 83/100
# 140/140 [==============================] - 9s 64ms/step - loss: 0.1249 - accuracy: 0.9619 - val_loss: 0.0662 - val_accuracy: 0.9810
# Epoch 84/100
# 140/140 [==============================] - 9s 61ms/step - loss: 0.1182 - accuracy: 0.9647 - val_loss: 0.0749 - val_accuracy: 0.9759
# Epoch 85/100
# 140/140 [==============================] - 9s 64ms/step - loss: 0.1109 - accuracy: 0.9643 - val_loss: 0.0731 - val_accuracy: 0.9790
# Epoch 86/100
# 140/140 [==============================] - 9s 60ms/step - loss: 0.1244 - accuracy: 0.9599 - val_loss: 0.0686 - val_accuracy: 0.9790
# Epoch 87/100
# 140/140 [==============================] - 10s 68ms/step - loss: 0.1181 - accuracy: 0.9619 - val_loss: 0.0667 - val_accuracy: 0.9821
# Epoch 88/100
# 140/140 [==============================] - 11s 81ms/step - loss: 0.1136 - accuracy: 0.9603 - val_loss: 0.0704 - val_accuracy: 0.9805
# Epoch 89/100
# 140/140 [==============================] - 10s 72ms/step - loss: 0.1112 - accuracy: 0.9634 - val_loss: 0.0776 - val_accuracy: 0.9775
# Epoch 90/100
# 140/140 [==============================] - 9s 60ms/step - loss: 0.1155 - accuracy: 0.9605 - val_loss: 0.0736 - val_accuracy: 0.9816
# Epoch 91/100
# 140/140 [==============================] - 9s 63ms/step - loss: 0.1151 - accuracy: 0.9623 - val_loss: 0.0768 - val_accuracy: 0.9785
# Epoch 92/100
# 140/140 [==============================] - 9s 65ms/step - loss: 0.0953 - accuracy: 0.9668 - val_loss: 0.0641 - val_accuracy: 0.9810
# Epoch 93/100
# 140/140 [==============================] - 10s 68ms/step - loss: 0.1076 - accuracy: 0.9630 - val_loss: 0.0641 - val_accuracy: 0.9795
# Epoch 94/100
# 140/140 [==============================] - 9s 63ms/step - loss: 0.1016 - accuracy: 0.9665 - val_loss: 0.0791 - val_accuracy: 0.9769
# Epoch 95/100
# 140/140 [==============================] - 10s 69ms/step - loss: 0.1062 - accuracy: 0.9623 - val_loss: 0.0625 - val_accuracy: 0.9816
# Epoch 96/100
# 140/140 [==============================] - 10s 71ms/step - loss: 0.0875 - accuracy: 0.9725 - val_loss: 0.0640 - val_accuracy: 0.9831
# Epoch 97/100
# 140/140 [==============================] - 8s 57ms/step - loss: 0.1041 - accuracy: 0.9630 - val_loss: 0.0839 - val_accuracy: 0.9764
# Epoch 98/100
# 140/140 [==============================] - 8s 60ms/step - loss: 0.1061 - accuracy: 0.9628 - val_loss: 0.0641 - val_accuracy: 0.9836
# Epoch 99/100
# 140/140 [==============================] - 8s 60ms/step - loss: 0.0969 - accuracy: 0.9703 - val_loss: 0.0739 - val_accuracy: 0.9810
# Epoch 100/100
# 140/140 [==============================] - 8s 54ms/step - loss: 0.0973 - accuracy: 0.9661 - val_loss: 0.0675 - val_accuracy: 0.9795

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig(r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\src\visualization\CNN\Accuracy_CNN2_1.png")

plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig(r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\src\visualization\CNN\Loss_CNN2_1.png")

plt.show()

# %%
Path_model=r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\models\CNN"
model.save(os.path.join(Path_model,"Amazigh_Handwritten_Recognition_CNN2_1.h5"))

# %%
from keras.models import load_model
#from sklearn.metrics import confusion_matrix
from mlxtend.evaluate import confusion_matrix


model = load_model(os.path.join(Path_model,"Amazigh_Handwritten_Recognition_CNN2_1.h5"))
# Predict the test data using the trained model
y_pred = model.predict(validation_generator)
# Out:
# 242/242 [==============================] - 4s 18ms/step

# %%
#Confution Matrix and Classification Report
target_names = ['ya', 'yab', 'yach', 'yad', 'yadd', 'yae', 'yaf', 'yag', 'yagh', 'yagw', 'yah', 'yahh', 'yaj',
                'yak', 'yakw', 'yal', 'yam', 'yan', 'yaq', 'yar', 'yarr', 'yas', 'yass', 'yat', 'yatt', 'yaw',
                'yax', 'yay', 'yaz', 'yazz', 'yey', 'yi', 'yu']
#print(classification_report(validation_generator.classes, y_pred, target_names=target_names))
y_pred = np.argmax(y_pred, axis=1)
print('Confusion Matrix')
conf_matrix=confusion_matrix(validation_generator.classes, y_pred)
print(conf_matrix)
# Out:
# Confusion Matrix
# [[244   0   0 ...   0   0   0]
#  [  0 223   0 ...   0   0   0]
#  [  0   1 222 ...   0   0   1]
#  ...
#  [  0   0   0 ... 215   0   1]
#  [  0   0   0 ...   0 219   0]
#  [  0   0   0 ...   0   0 233]]

# %%
from sklearn.metrics import classification_report

print('Classification Report')

print(classification_report(validation_generator.classes, y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#           ya       1.00      1.00      1.00       244
#          yab       1.00      0.98      0.99       228
#         yach       0.97      0.98      0.97       226
#          yad       1.00      0.99      0.99       238
#         yadd       1.00      0.99      0.99       245
#          yae       0.99      0.99      0.99       243
#          yaf       0.98      0.99      0.99       217
#          yag       0.96      1.00      0.98       221
#         yagh       1.00      0.99      0.99       237
#         yagw       0.98      0.99      0.99       240
#          yah       0.99      0.98      0.98       245
#         yahh       0.98      1.00      0.99       240
#          yaj       0.95      0.97      0.96       225
#          yak       0.98      0.94      0.96       227
#         yakw       0.98      0.98      0.98       244
#          yal       0.99      0.98      0.98       245
#          yam       0.99      0.96      0.98       254
#          yan       1.00      0.97      0.98       265
#          yaq       0.95      1.00      0.97       236
#          yar       0.98      0.98      0.98       243
#         yarr       0.93      0.97      0.95       228
#          yas       0.98      0.96      0.97       228
#         yass       0.97      0.99      0.98       237
#          yat       1.00      0.99      1.00       225
#         yatt       1.00      0.97      0.98       250
#          yaw       1.00      0.99      0.99       212
#          yax       0.98      0.99      0.98       222
#          yay       0.98      0.96      0.97       220
#          yaz       0.93      0.98      0.96       240
#         yazz       0.99      0.95      0.97       225
#          yey       1.00      1.00      1.00       216
#           yi       0.96      0.98      0.97       223
#           yu       0.99      1.00      1.00       233
#
#     accuracy                           0.98      7722
#    macro avg       0.98      0.98      0.98      7722
# weighted avg       0.98      0.98      0.98      7722

# %%
import matplotlib.pyplot as plt
import numpy as np
import itertools
def plot_confusion_matrix(cm, target_names, title='Confusion matrix', cmap=None, normalize=False):
    """
    arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions
    """
     
    if cmap is None:
        cmap = plt.get_cmap('YlGnBu')

    plt.figure(figsize=(20, 20))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    
    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylim(len(target_names)-0.5, -0.5)
    plt.ylabel('True labels')
    plt.xlabel('Predicted labels')
    #plt.savefig(r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\src\visualization\CNN\Loss_3.png")
    plt.savefig(r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\src\visualization\CNN\Confusion_matrix_CNN2_1.png", dpi=500, bbox_inches = 'tight')
    plt.show()
    
from keras.models import load_model
plot_confusion_matrix(conf_matrix, target_names)
