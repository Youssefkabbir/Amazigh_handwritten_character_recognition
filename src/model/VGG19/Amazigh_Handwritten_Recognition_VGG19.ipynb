# %% [markdown]
# # The first step is to import the required Librairies

# %%
"""pandas is a Python package that provides fast, flexible, and expressive data structures
designed to make working with "relational" or "labeled" data both easy and intuitive."""
import pandas as pd
"""NumPy is a Python library used for working with arrays.
It also has functions for working in domain of linear algebra, fourier transform, and matrices."""
import numpy as np

"""Matplotlib is a comprehensive library for creating static, animated, and interactive
visualizations in Python. Matplotlib makes easy things easy and hard things possible."""
import  matplotlib.pyplot as plt 
"""OpenCV is the huge open-source library for the computer vision, machine learning, and image 
processing and now it plays a major role in real-time operation which is very important
in today’s systems"""
import cv2
"""This module provides a portable way of using operating system dependent functionality. If you
just want to read or write a file see open(), if you want to manipulate paths, see the os.path 
module, and if you want to read all the lines in all the files on the command line see the 
fileinput module"""
import os
"""The Python Imaging Library adds image processing capabilities to your Python interpreter.
This library provides extensive file format support, an efficient internal representation, 
and fairly powerful image processing capabilities."""
from PIL import Image
"""scikit-learn is a Python module for machine learning built on top of SciPy and is distributed
under the 3-Clause BSD license."""
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import itertools
"""Tensorflow is one of the most-used deep-learning frameworks. It’s arguably the most popular
machine learning platform on the web, with a broad range of users from those just starting out, 
to people looking for an edge in their careers and businesses. """
import tensorflow as tf 
from tensorflow.keras.utils import  to_categorical
from tensorflow.keras.models import Sequential ,load_model
from tensorflow.keras.layers import Conv2D,MaxPool2D,Dense ,Flatten,Dropout
print('the cell was executed without errors')
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16 
from tensorflow.keras.applications.vgg19 import   VGG19
#from keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras import layers, models, Model, optimizers
from tensorflow.keras.optimizers import RMSprop,SGD,Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
# Out:
# the cell was executed without errors

# %% [markdown]
# # We are going to load our Dataset

# %%
Path_Data=r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\data\processed"
Data=pd.read_csv(os.path.join(Path_Data,"Data.csv"))

# %%
data_path=r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\data\raw\AMHCD_64"
categories=os.listdir(data_path)
print(categories)
number_Classes=len(categories)
print(number_Classes)
# Out:
# ['ya', 'yab', 'yach', 'yad', 'yadd', 'yae', 'yaf', 'yag', 'yagh', 'yagw', 'yah', 'yahh', 'yaj', 'yak', 'yakw', 'yal', 'yam', 'yan', 'yaq', 'yar', 'yarr', 'yas', 'yass', 'yat', 'yatt', 'yaw', 'yax', 'yay', 'yaz', 'yazz', 'yey', 'yi', 'yu']
# 33

# %%
"""
Data['Classes']=Data['Classes'].astype(str)

dummies =pd.get_dummies(Data['Classes'],drop_first=True).astype(int)
Examples=Data['Path']

merged = pd.concat([Examples,dummies],axis=1)
labels=('ya', 'yab', 'yach', 'yad', 'yadd', 'yae', 'yaf', 'yag', 'yagh', 'yagw', 'yah', 'yahh', 'yaj', 'yak', 'yakw'
        , 'yal', 'yam', 'yan', 'yaq', 'yar', 'yarr', 'yas', 'yass', 'yat', 'yatt', 'yaw', 'yax', 'yay', 'yaz', 'yazz'
        , 'yey', 'yi', 'yu')"""
# Out:
# "\nData['Classes']=Data['Classes'].astype(str)\n\ndummies =pd.get_dummies(Data['Classes'],drop_first=True).astype(int)\nExamples=Data['Path']\n\nmerged = pd.concat([Examples,dummies],axis=1)\nlabels=('ya', 'yab', 'yach', 'yad', 'yadd', 'yae', 'yaf', 'yag', 'yagh', 'yagw', 'yah', 'yahh', 'yaj', 'yak', 'yakw'\n        , 'yal', 'yam', 'yan', 'yaq', 'yar', 'yarr', 'yas', 'yass', 'yat', 'yatt', 'yaw', 'yax', 'yay', 'yaz', 'yazz'\n        , 'yey', 'yi', 'yu')"

# %%
from sklearn.model_selection import train_test_split
Train, Validation = train_test_split(Data, test_size = 0.3, random_state = 20)
train_datagen =  ImageDataGenerator(rescale=1. / 255,zoom_range=[0.7,1.0])

test_datagen = ImageDataGenerator( rescale=1./255)
print('the cell was executed without errors')
Train
# Out:
# the cell was executed without errors
#                                                     Path Classes
# 18692  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yat
# 22295  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yaz
# 18625  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yat
# 13017  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yam
# 8869   C:\Users\kabir\Desktop\Projects\Amazigh_handwr...    yahh
# ...                                                  ...     ...
# 14729  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yaq
# 23452  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yey
# 23775  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yey
# 4367   C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yae
# 15715  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...    yarr
#
# [18018 rows x 2 columns]

# %%
train_generator=train_datagen.flow_from_dataframe(
dataframe=Train,
directory=data_path,
x_col='Path',
y_col='Classes',
batch_size=128,
seed=42,
shuffle=False,
class_mode="categorical",
#class_mode="sparse",

target_size=(64,64))
# Out:
# Found 18018 validated image filenames belonging to 33 classes.

# %%
validation_generator=test_datagen.flow_from_dataframe(
dataframe=Validation,
directory=data_path,
x_col='Path',
y_col='Classes',
batch_size=128,
seed=42,
shuffle=False,
class_mode="categorical",

#class_mode="sparse",
target_size=(64,64))

print('the cell was executed without errors')
# Out:
# Found 7722 validated image filenames belonging to 33 classes.
# the cell was executed without errors

# %%
img_input=(64, 64, 3)
vgg=VGG19(weights='imagenet', include_top=False,pooling='avg', input_shape=img_input)
for layer in vgg.layers:
    layer.trainable = False
x = vgg.output
x = Dense(64, activation="relu")(x)
x = Dropout(0.4)(x)
x = Flatten(name="flatten")(x)
x = Dense(2048, activation='relu')(x)
prd = Dense(number_Classes,activation='softmax')(x)
model = Model(inputs=vgg.input, outputs=prd)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 64, 64, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 64, 64, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 32, 32, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 32, 32, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 32, 32, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 16, 16, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 16, 16, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 8, 8, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 8, 8, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_conv4 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 64)                32832
#
#  dropout (Dropout)           (None, 64)                0
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 2048)              133120
#
#  dense_2 (Dense)             (None, 33)                67617
#
# =================================================================
# Total params: 20,257,953
# Trainable params: 233,569
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
Path_Weights=r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\models\CNN"
#//checking checkpoint for selecting the best model for the emotion detection and save the best model with minimum validation loss having the name written on it in the current working folder
checkpoint = ModelCheckpoint(r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\models\VGG19\Weights\Weight_VGG19_1.h5",
                             monitor='val_loss',
                             mode='min',
                             save_best_only=True,
                             verbose=1)

#//reduce_lr will also monitor the validation loss 
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.1,
                              patience=2,
                              verbose=1,
                              min_lr=.000001)
#callb = [earlystop, checkpoint, reduce_lr]

call=[ checkpoint,reduce_lr]

# %%
adam = Adam(learning_rate=.0001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
s=train_generator.n/16
print(s)
# Out:
# 1126.125

# %%
batch_size=512
#//This last block of codes will train our codes with the given parameters where it will fit train generator for training epochs to 25, callbacks will call the earlystop, checkpoint and reduce_lr and validation data will be equal to validation generator which was created on the first execution 
history = model.fit_generator(generator=train_generator,steps_per_epoch=train_generator.n/batch_size, epochs=150
                              ,validation_data=validation_generator,validation_steps=validation_generator.n/batch_size)
# Out:
# C:\Users\kabir\AppData\Local\Temp\ipykernel_12660\3839027333.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(generator=train_generator,steps_per_epoch=train_generator.n/batch_size, epochs=150
# Epoch 1/150
# 35/35 [==============================] - 29s 316ms/step - loss: 3.4517 - accuracy: 0.0694 - val_loss: 3.3707 - val_accuracy: 0.2231
# Epoch 2/150
# 35/35 [==============================] - 11s 300ms/step - loss: 3.2986 - accuracy: 0.1840 - val_loss: 3.1600 - val_accuracy: 0.3291
# Epoch 3/150
# 35/35 [==============================] - 10s 289ms/step - loss: 3.0475 - accuracy: 0.2520 - val_loss: 2.8132 - val_accuracy: 0.4326
# Epoch 4/150
# 35/35 [==============================] - 15s 424ms/step - loss: 2.7473 - accuracy: 0.2910 - val_loss: 2.4446 - val_accuracy: 0.4829
# Epoch 5/150
# 35/35 [==============================] - 10s 284ms/step - loss: 2.4117 - accuracy: 0.3661 - val_loss: 2.1218 - val_accuracy: 0.5244
# Epoch 6/150
# 35/35 [==============================] - 10s 276ms/step - loss: 2.1690 - accuracy: 0.3904 - val_loss: 1.8777 - val_accuracy: 0.5708
# Epoch 7/150
# 35/35 [==============================] - 11s 284ms/step - loss: 1.9947 - accuracy: 0.4284 - val_loss: 1.6820 - val_accuracy: 0.6343
# Epoch 8/150
# 35/35 [==============================] - 10s 267ms/step - loss: 1.8000 - accuracy: 0.4774 - val_loss: 1.5287 - val_accuracy: 0.6655
# Epoch 9/150
# 35/35 [==============================] - 9s 263ms/step - loss: 1.6874 - accuracy: 0.4970 - val_loss: 1.4180 - val_accuracy: 0.6533
# Epoch 10/150
# 35/35 [==============================] - 13s 362ms/step - loss: 1.5719 - accuracy: 0.5367 - val_loss: 1.2968 - val_accuracy: 0.7139
# Epoch 11/150
# 35/35 [==============================] - 11s 301ms/step - loss: 1.5038 - accuracy: 0.5297 - val_loss: 1.2215 - val_accuracy: 0.7197
# Epoch 12/150
# 35/35 [==============================] - 10s 282ms/step - loss: 1.4100 - accuracy: 0.5679 - val_loss: 1.1423 - val_accuracy: 0.7383
# Epoch 13/150
# 35/35 [==============================] - 9s 263ms/step - loss: 1.3376 - accuracy: 0.5866 - val_loss: 1.0873 - val_accuracy: 0.7373
# Epoch 14/150
# 35/35 [==============================] - 9s 260ms/step - loss: 1.2845 - accuracy: 0.5952 - val_loss: 1.0346 - val_accuracy: 0.7563
# Epoch 15/150
# 35/35 [==============================] - 9s 262ms/step - loss: 1.2206 - accuracy: 0.6152 - val_loss: 1.0024 - val_accuracy: 0.7461
# Epoch 16/150
# 35/35 [==============================] - 9s 256ms/step - loss: 1.1576 - accuracy: 0.6372 - val_loss: 0.9480 - val_accuracy: 0.7676
# Epoch 17/150
# 35/35 [==============================] - 10s 294ms/step - loss: 1.1338 - accuracy: 0.6464 - val_loss: 0.9036 - val_accuracy: 0.7852
# Epoch 18/150
# 35/35 [==============================] - 11s 299ms/step - loss: 1.1001 - accuracy: 0.6513 - val_loss: 0.8692 - val_accuracy: 0.7910
# Epoch 19/150
# 35/35 [==============================] - 9s 261ms/step - loss: 1.0536 - accuracy: 0.6667 - val_loss: 0.8190 - val_accuracy: 0.7988
# Epoch 20/150
# 35/35 [==============================] - 10s 269ms/step - loss: 1.0339 - accuracy: 0.6654 - val_loss: 0.8180 - val_accuracy: 0.7920
# Epoch 21/150
# 35/35 [==============================] - 9s 256ms/step - loss: 1.0064 - accuracy: 0.6797 - val_loss: 0.7776 - val_accuracy: 0.8169
# Epoch 22/150
# 35/35 [==============================] - 9s 265ms/step - loss: 0.9751 - accuracy: 0.6842 - val_loss: 0.7611 - val_accuracy: 0.8047
# Epoch 23/150
# 35/35 [==============================] - 10s 277ms/step - loss: 0.9533 - accuracy: 0.6947 - val_loss: 0.7532 - val_accuracy: 0.7998
# Epoch 24/150
# 35/35 [==============================] - 9s 262ms/step - loss: 0.9205 - accuracy: 0.7007 - val_loss: 0.7320 - val_accuracy: 0.8110
# Epoch 25/150
# 35/35 [==============================] - 10s 273ms/step - loss: 0.9117 - accuracy: 0.7038 - val_loss: 0.7103 - val_accuracy: 0.8301
# Epoch 26/150
# 35/35 [==============================] - 10s 269ms/step - loss: 0.9014 - accuracy: 0.7135 - val_loss: 0.7001 - val_accuracy: 0.8174
# Epoch 27/150
# 35/35 [==============================] - 9s 263ms/step - loss: 0.9024 - accuracy: 0.7151 - val_loss: 0.6892 - val_accuracy: 0.8213
# Epoch 28/150
# 35/35 [==============================] - 9s 266ms/step - loss: 0.8639 - accuracy: 0.7227 - val_loss: 0.6667 - val_accuracy: 0.8252
# Epoch 29/150
# 35/35 [==============================] - 9s 267ms/step - loss: 0.8562 - accuracy: 0.7250 - val_loss: 0.6580 - val_accuracy: 0.8340
# Epoch 30/150
# 35/35 [==============================] - 12s 324ms/step - loss: 0.8134 - accuracy: 0.7396 - val_loss: 0.6467 - val_accuracy: 0.8247
# Epoch 31/150
# 35/35 [==============================] - 10s 284ms/step - loss: 0.8323 - accuracy: 0.7409 - val_loss: 0.6449 - val_accuracy: 0.8286
# Epoch 32/150
# 35/35 [==============================] - 10s 277ms/step - loss: 0.7963 - accuracy: 0.7333 - val_loss: 0.6164 - val_accuracy: 0.8354
# Epoch 33/150
# 35/35 [==============================] - 9s 267ms/step - loss: 0.7873 - accuracy: 0.7467 - val_loss: 0.6110 - val_accuracy: 0.8398
# Epoch 34/150
# 35/35 [==============================] - 10s 286ms/step - loss: 0.7853 - accuracy: 0.7479 - val_loss: 0.5893 - val_accuracy: 0.8486
# Epoch 35/150
# 35/35 [==============================] - 9s 265ms/step - loss: 0.7778 - accuracy: 0.7418 - val_loss: 0.5810 - val_accuracy: 0.8501
# Epoch 36/150
# 35/35 [==============================] - 9s 266ms/step - loss: 0.7567 - accuracy: 0.7591 - val_loss: 0.5689 - val_accuracy: 0.8530
# Epoch 37/150
# 35/35 [==============================] - 10s 287ms/step - loss: 0.7686 - accuracy: 0.7565 - val_loss: 0.5840 - val_accuracy: 0.8530
# Epoch 38/150
# 35/35 [==============================] - 10s 297ms/step - loss: 0.7543 - accuracy: 0.7580 - val_loss: 0.5584 - val_accuracy: 0.8569
# Epoch 39/150
# 35/35 [==============================] - 11s 320ms/step - loss: 0.7251 - accuracy: 0.7639 - val_loss: 0.5432 - val_accuracy: 0.8604
# Epoch 40/150
# 35/35 [==============================] - 10s 294ms/step - loss: 0.6997 - accuracy: 0.7758 - val_loss: 0.5603 - val_accuracy: 0.8477
# Epoch 41/150
# 35/35 [==============================] - 10s 293ms/step - loss: 0.7077 - accuracy: 0.7730 - val_loss: 0.5354 - val_accuracy: 0.8638
# Epoch 42/150
# 35/35 [==============================] - 10s 283ms/step - loss: 0.6914 - accuracy: 0.7726 - val_loss: 0.5349 - val_accuracy: 0.8579
# Epoch 43/150
# 35/35 [==============================] - 11s 300ms/step - loss: 0.7208 - accuracy: 0.7715 - val_loss: 0.5340 - val_accuracy: 0.8555
# Epoch 44/150
# 35/35 [==============================] - 9s 266ms/step - loss: 0.7016 - accuracy: 0.7639 - val_loss: 0.5284 - val_accuracy: 0.8608
# Epoch 45/150
# 35/35 [==============================] - 9s 259ms/step - loss: 0.7043 - accuracy: 0.7698 - val_loss: 0.5337 - val_accuracy: 0.8481
# Epoch 46/150
# 35/35 [==============================] - 10s 275ms/step - loss: 0.6992 - accuracy: 0.7818 - val_loss: 0.5052 - val_accuracy: 0.8647
# Epoch 47/150
# 35/35 [==============================] - 9s 265ms/step - loss: 0.6647 - accuracy: 0.7819 - val_loss: 0.4981 - val_accuracy: 0.8726
# Epoch 48/150
# 35/35 [==============================] - 10s 271ms/step - loss: 0.6666 - accuracy: 0.7893 - val_loss: 0.4866 - val_accuracy: 0.8735
# Epoch 49/150
# 35/35 [==============================] - 10s 277ms/step - loss: 0.6651 - accuracy: 0.7841 - val_loss: 0.4852 - val_accuracy: 0.8711
# Epoch 50/150
# 35/35 [==============================] - 9s 264ms/step - loss: 0.6394 - accuracy: 0.7923 - val_loss: 0.5051 - val_accuracy: 0.8550
# Epoch 51/150
# 35/35 [==============================] - 10s 274ms/step - loss: 0.6472 - accuracy: 0.7949 - val_loss: 0.4794 - val_accuracy: 0.8779
# Epoch 52/150
# 35/35 [==============================] - 10s 271ms/step - loss: 0.6294 - accuracy: 0.7951 - val_loss: 0.4764 - val_accuracy: 0.8643
# Epoch 53/150
# 35/35 [==============================] - 10s 278ms/step - loss: 0.6206 - accuracy: 0.7982 - val_loss: 0.4643 - val_accuracy: 0.8750
# Epoch 54/150
# 35/35 [==============================] - 9s 259ms/step - loss: 0.6323 - accuracy: 0.7997 - val_loss: 0.4713 - val_accuracy: 0.8696
# Epoch 55/150
# 35/35 [==============================] - 10s 274ms/step - loss: 0.6110 - accuracy: 0.7980 - val_loss: 0.4521 - val_accuracy: 0.8804
# Epoch 56/150
# 35/35 [==============================] - 10s 270ms/step - loss: 0.6026 - accuracy: 0.8021 - val_loss: 0.4384 - val_accuracy: 0.8838
# Epoch 57/150
# 35/35 [==============================] - 10s 271ms/step - loss: 0.6220 - accuracy: 0.7936 - val_loss: 0.4535 - val_accuracy: 0.8711
# Epoch 58/150
# 35/35 [==============================] - 10s 273ms/step - loss: 0.5963 - accuracy: 0.8118 - val_loss: 0.4424 - val_accuracy: 0.8794
# Epoch 59/150
# 35/35 [==============================] - 13s 370ms/step - loss: 0.6065 - accuracy: 0.8092 - val_loss: 0.4487 - val_accuracy: 0.8770
# Epoch 60/150
# 35/35 [==============================] - 9s 263ms/step - loss: 0.5980 - accuracy: 0.8080 - val_loss: 0.4285 - val_accuracy: 0.8896
# Epoch 61/150
# 35/35 [==============================] - 10s 287ms/step - loss: 0.5890 - accuracy: 0.8118 - val_loss: 0.4405 - val_accuracy: 0.8774
# Epoch 62/150
# 35/35 [==============================] - 10s 288ms/step - loss: 0.5721 - accuracy: 0.8086 - val_loss: 0.4331 - val_accuracy: 0.8784
# Epoch 63/150
# 35/35 [==============================] - 10s 272ms/step - loss: 0.5943 - accuracy: 0.8089 - val_loss: 0.4128 - val_accuracy: 0.8901
# Epoch 64/150
# 35/35 [==============================] - 10s 275ms/step - loss: 0.5552 - accuracy: 0.8152 - val_loss: 0.4140 - val_accuracy: 0.8892
# Epoch 65/150
# 35/35 [==============================] - 11s 325ms/step - loss: 0.5625 - accuracy: 0.8173 - val_loss: 0.4163 - val_accuracy: 0.8892
# Epoch 66/150
# 35/35 [==============================] - 11s 297ms/step - loss: 0.5392 - accuracy: 0.8294 - val_loss: 0.4045 - val_accuracy: 0.8926
# Epoch 67/150
# 35/35 [==============================] - 11s 312ms/step - loss: 0.5740 - accuracy: 0.8158 - val_loss: 0.4194 - val_accuracy: 0.8809
# Epoch 68/150
# 35/35 [==============================] - 10s 286ms/step - loss: 0.5513 - accuracy: 0.8244 - val_loss: 0.4088 - val_accuracy: 0.8887
# Epoch 69/150
# 35/35 [==============================] - 11s 311ms/step - loss: 0.5461 - accuracy: 0.8201 - val_loss: 0.4153 - val_accuracy: 0.8887
# Epoch 70/150
# 35/35 [==============================] - 10s 295ms/step - loss: 0.5545 - accuracy: 0.8171 - val_loss: 0.3961 - val_accuracy: 0.8911
# Epoch 71/150
# 35/35 [==============================] - 10s 288ms/step - loss: 0.5546 - accuracy: 0.8181 - val_loss: 0.3968 - val_accuracy: 0.8911
# Epoch 72/150
# 35/35 [==============================] - 10s 292ms/step - loss: 0.5406 - accuracy: 0.8288 - val_loss: 0.3963 - val_accuracy: 0.8960
# Epoch 73/150
# 35/35 [==============================] - 12s 333ms/step - loss: 0.5256 - accuracy: 0.8283 - val_loss: 0.3875 - val_accuracy: 0.8896
# Epoch 74/150
# 35/35 [==============================] - 11s 314ms/step - loss: 0.5264 - accuracy: 0.8298 - val_loss: 0.3969 - val_accuracy: 0.8916
# Epoch 75/150
# 35/35 [==============================] - 10s 289ms/step - loss: 0.5427 - accuracy: 0.8218 - val_loss: 0.3785 - val_accuracy: 0.8984
# Epoch 76/150
# 35/35 [==============================] - 11s 301ms/step - loss: 0.5037 - accuracy: 0.8392 - val_loss: 0.3893 - val_accuracy: 0.8892
# Epoch 77/150
# 35/35 [==============================] - 10s 295ms/step - loss: 0.5320 - accuracy: 0.8246 - val_loss: 0.3818 - val_accuracy: 0.8940
# Epoch 78/150
# 35/35 [==============================] - 11s 314ms/step - loss: 0.5099 - accuracy: 0.8368 - val_loss: 0.3827 - val_accuracy: 0.8882
# Epoch 79/150
# 35/35 [==============================] - 11s 319ms/step - loss: 0.5251 - accuracy: 0.8351 - val_loss: 0.3643 - val_accuracy: 0.8999
# Epoch 80/150
# 35/35 [==============================] - 9s 266ms/step - loss: 0.5174 - accuracy: 0.8353 - val_loss: 0.3629 - val_accuracy: 0.9053
# Epoch 81/150
# 35/35 [==============================] - 9s 262ms/step - loss: 0.5024 - accuracy: 0.8349 - val_loss: 0.3860 - val_accuracy: 0.8911
# Epoch 82/150
# 35/35 [==============================] - 9s 268ms/step - loss: 0.4819 - accuracy: 0.8445 - val_loss: 0.3673 - val_accuracy: 0.9023
# Epoch 83/150
# 35/35 [==============================] - 9s 266ms/step - loss: 0.5178 - accuracy: 0.8299 - val_loss: 0.3717 - val_accuracy: 0.8979
# Epoch 84/150
# 35/35 [==============================] - 10s 275ms/step - loss: 0.4925 - accuracy: 0.8362 - val_loss: 0.3644 - val_accuracy: 0.8984
# Epoch 85/150
# 35/35 [==============================] - 10s 272ms/step - loss: 0.5066 - accuracy: 0.8336 - val_loss: 0.3678 - val_accuracy: 0.8994
# Epoch 86/150
# 35/35 [==============================] - 10s 268ms/step - loss: 0.4922 - accuracy: 0.8338 - val_loss: 0.3686 - val_accuracy: 0.8965
# Epoch 87/150
# 35/35 [==============================] - 10s 271ms/step - loss: 0.4863 - accuracy: 0.8421 - val_loss: 0.3587 - val_accuracy: 0.8965
# Epoch 88/150
# 35/35 [==============================] - 10s 269ms/step - loss: 0.4991 - accuracy: 0.8446 - val_loss: 0.3659 - val_accuracy: 0.8965
# Epoch 89/150
# 35/35 [==============================] - 10s 278ms/step - loss: 0.4984 - accuracy: 0.8322 - val_loss: 0.3451 - val_accuracy: 0.9043
# Epoch 90/150
# 35/35 [==============================] - 10s 269ms/step - loss: 0.4820 - accuracy: 0.8433 - val_loss: 0.3517 - val_accuracy: 0.9033
# Epoch 91/150
# 35/35 [==============================] - 10s 270ms/step - loss: 0.5085 - accuracy: 0.8377 - val_loss: 0.3482 - val_accuracy: 0.9058
# Epoch 92/150
# 35/35 [==============================] - 10s 276ms/step - loss: 0.4601 - accuracy: 0.8544 - val_loss: 0.3485 - val_accuracy: 0.9067
# Epoch 93/150
# 35/35 [==============================] - 10s 275ms/step - loss: 0.4638 - accuracy: 0.8461 - val_loss: 0.3379 - val_accuracy: 0.9048
# Epoch 94/150
# 35/35 [==============================] - 10s 273ms/step - loss: 0.4691 - accuracy: 0.8513 - val_loss: 0.3489 - val_accuracy: 0.9009
# Epoch 95/150
# 35/35 [==============================] - 11s 300ms/step - loss: 0.4549 - accuracy: 0.8524 - val_loss: 0.3334 - val_accuracy: 0.9092
# Epoch 96/150
# 35/35 [==============================] - 10s 285ms/step - loss: 0.4806 - accuracy: 0.8429 - val_loss: 0.3431 - val_accuracy: 0.9033
# Epoch 97/150
# 35/35 [==============================] - 10s 276ms/step - loss: 0.4668 - accuracy: 0.8499 - val_loss: 0.3267 - val_accuracy: 0.9082
# Epoch 98/150
# 35/35 [==============================] - 11s 306ms/step - loss: 0.4385 - accuracy: 0.8574 - val_loss: 0.3391 - val_accuracy: 0.9053
# Epoch 99/150
# 35/35 [==============================] - 10s 275ms/step - loss: 0.4629 - accuracy: 0.8557 - val_loss: 0.3233 - val_accuracy: 0.9106
# Epoch 100/150
# 35/35 [==============================] - 10s 279ms/step - loss: 0.4668 - accuracy: 0.8488 - val_loss: 0.3159 - val_accuracy: 0.9165
# Epoch 101/150
# 35/35 [==============================] - 10s 276ms/step - loss: 0.4523 - accuracy: 0.8513 - val_loss: 0.3342 - val_accuracy: 0.9072
# Epoch 102/150
# 35/35 [==============================] - 10s 285ms/step - loss: 0.4490 - accuracy: 0.8533 - val_loss: 0.3287 - val_accuracy: 0.9048
# Epoch 103/150
# 35/35 [==============================] - 10s 274ms/step - loss: 0.4363 - accuracy: 0.8545 - val_loss: 0.3250 - val_accuracy: 0.9106
# Epoch 104/150
# 35/35 [==============================] - 10s 271ms/step - loss: 0.4478 - accuracy: 0.8589 - val_loss: 0.3306 - val_accuracy: 0.9062
# Epoch 105/150
# 35/35 [==============================] - 12s 331ms/step - loss: 0.4492 - accuracy: 0.8548 - val_loss: 0.3268 - val_accuracy: 0.9048
# Epoch 106/150
# 35/35 [==============================] - 11s 303ms/step - loss: 0.4508 - accuracy: 0.8513 - val_loss: 0.3239 - val_accuracy: 0.9082
# Epoch 107/150
# 35/35 [==============================] - 11s 299ms/step - loss: 0.4687 - accuracy: 0.8495 - val_loss: 0.3111 - val_accuracy: 0.9131
# Epoch 108/150
# 35/35 [==============================] - 10s 278ms/step - loss: 0.4382 - accuracy: 0.8624 - val_loss: 0.3019 - val_accuracy: 0.9136
# Epoch 109/150
# 35/35 [==============================] - 10s 286ms/step - loss: 0.4410 - accuracy: 0.8559 - val_loss: 0.3134 - val_accuracy: 0.9082
# Epoch 110/150
# 35/35 [==============================] - 10s 276ms/step - loss: 0.4248 - accuracy: 0.8633 - val_loss: 0.3185 - val_accuracy: 0.9111
# Epoch 111/150
# 35/35 [==============================] - 10s 283ms/step - loss: 0.4250 - accuracy: 0.8587 - val_loss: 0.3153 - val_accuracy: 0.9067
# Epoch 112/150
# 35/35 [==============================] - 12s 333ms/step - loss: 0.4382 - accuracy: 0.8593 - val_loss: 0.3156 - val_accuracy: 0.9111
# Epoch 113/150
# 35/35 [==============================] - 10s 285ms/step - loss: 0.4173 - accuracy: 0.8668 - val_loss: 0.3012 - val_accuracy: 0.9136
# Epoch 114/150
# 35/35 [==============================] - 11s 320ms/step - loss: 0.4128 - accuracy: 0.8672 - val_loss: 0.3070 - val_accuracy: 0.9116
# Epoch 115/150
# 35/35 [==============================] - 11s 315ms/step - loss: 0.4174 - accuracy: 0.8659 - val_loss: 0.3105 - val_accuracy: 0.9087
# Epoch 116/150
# 35/35 [==============================] - 11s 321ms/step - loss: 0.4277 - accuracy: 0.8652 - val_loss: 0.3003 - val_accuracy: 0.9111
# Epoch 117/150
# 35/35 [==============================] - 10s 275ms/step - loss: 0.3989 - accuracy: 0.8783 - val_loss: 0.3062 - val_accuracy: 0.9106
# Epoch 118/150
# 35/35 [==============================] - 10s 286ms/step - loss: 0.4317 - accuracy: 0.8613 - val_loss: 0.3114 - val_accuracy: 0.9072
# Epoch 119/150
# 35/35 [==============================] - 11s 298ms/step - loss: 0.4284 - accuracy: 0.8618 - val_loss: 0.2879 - val_accuracy: 0.9189
# Epoch 120/150
# 35/35 [==============================] - 10s 290ms/step - loss: 0.4284 - accuracy: 0.8609 - val_loss: 0.3104 - val_accuracy: 0.9106
# Epoch 121/150
# 35/35 [==============================] - 10s 278ms/step - loss: 0.4259 - accuracy: 0.8620 - val_loss: 0.3078 - val_accuracy: 0.9116
# Epoch 122/150
# 35/35 [==============================] - 10s 285ms/step - loss: 0.4200 - accuracy: 0.8672 - val_loss: 0.2914 - val_accuracy: 0.9165
# Epoch 123/150
# 35/35 [==============================] - 10s 286ms/step - loss: 0.3899 - accuracy: 0.8713 - val_loss: 0.3026 - val_accuracy: 0.9126
# Epoch 124/150
# 35/35 [==============================] - 10s 285ms/step - loss: 0.4138 - accuracy: 0.8700 - val_loss: 0.2893 - val_accuracy: 0.9141
# Epoch 125/150
# 35/35 [==============================] - 10s 296ms/step - loss: 0.4190 - accuracy: 0.8659 - val_loss: 0.2900 - val_accuracy: 0.9141
# Epoch 126/150
# 35/35 [==============================] - 10s 275ms/step - loss: 0.4141 - accuracy: 0.8674 - val_loss: 0.2901 - val_accuracy: 0.9150
# Epoch 127/150
# 35/35 [==============================] - 10s 283ms/step - loss: 0.3877 - accuracy: 0.8750 - val_loss: 0.2960 - val_accuracy: 0.9160
# Epoch 128/150
# 35/35 [==============================] - 11s 304ms/step - loss: 0.4123 - accuracy: 0.8711 - val_loss: 0.2896 - val_accuracy: 0.9189
# Epoch 129/150
# 35/35 [==============================] - 10s 278ms/step - loss: 0.3988 - accuracy: 0.8674 - val_loss: 0.2906 - val_accuracy: 0.9141
# Epoch 130/150
# 35/35 [==============================] - 10s 283ms/step - loss: 0.3847 - accuracy: 0.8789 - val_loss: 0.2942 - val_accuracy: 0.9155
# Epoch 131/150
# 35/35 [==============================] - 18s 511ms/step - loss: 0.3998 - accuracy: 0.8704 - val_loss: 0.2781 - val_accuracy: 0.9194
# Epoch 132/150
# 35/35 [==============================] - 19s 535ms/step - loss: 0.3873 - accuracy: 0.8722 - val_loss: 0.2784 - val_accuracy: 0.9214
# Epoch 133/150
# 35/35 [==============================] - 19s 535ms/step - loss: 0.3971 - accuracy: 0.8704 - val_loss: 0.2903 - val_accuracy: 0.9155
# Epoch 134/150
# 35/35 [==============================] - 19s 537ms/step - loss: 0.3923 - accuracy: 0.8750 - val_loss: 0.2743 - val_accuracy: 0.9214
# Epoch 135/150
# 35/35 [==============================] - 19s 537ms/step - loss: 0.3764 - accuracy: 0.8770 - val_loss: 0.2812 - val_accuracy: 0.9189
# Epoch 136/150
# 35/35 [==============================] - 19s 538ms/step - loss: 0.4133 - accuracy: 0.8637 - val_loss: 0.2795 - val_accuracy: 0.9199
# Epoch 137/150
# 35/35 [==============================] - 19s 536ms/step - loss: 0.3709 - accuracy: 0.8778 - val_loss: 0.2802 - val_accuracy: 0.9204
# Epoch 138/150
# 35/35 [==============================] - 19s 537ms/step - loss: 0.3891 - accuracy: 0.8674 - val_loss: 0.2767 - val_accuracy: 0.9180
# Epoch 139/150
# 35/35 [==============================] - 19s 545ms/step - loss: 0.3821 - accuracy: 0.8770 - val_loss: 0.2762 - val_accuracy: 0.9189
# Epoch 140/150
# 35/35 [==============================] - 19s 540ms/step - loss: 0.4007 - accuracy: 0.8704 - val_loss: 0.2824 - val_accuracy: 0.9180
# Epoch 141/150
# 35/35 [==============================] - 19s 547ms/step - loss: 0.3893 - accuracy: 0.8748 - val_loss: 0.2748 - val_accuracy: 0.9219
# Epoch 142/150
# 35/35 [==============================] - 19s 538ms/step - loss: 0.3981 - accuracy: 0.8702 - val_loss: 0.2693 - val_accuracy: 0.9219
# Epoch 143/150
# 35/35 [==============================] - 19s 538ms/step - loss: 0.3942 - accuracy: 0.8741 - val_loss: 0.2807 - val_accuracy: 0.9165
# Epoch 144/150
# 35/35 [==============================] - 19s 535ms/step - loss: 0.3781 - accuracy: 0.8787 - val_loss: 0.2696 - val_accuracy: 0.9219
# Epoch 145/150
# 35/35 [==============================] - 19s 536ms/step - loss: 0.3765 - accuracy: 0.8783 - val_loss: 0.2718 - val_accuracy: 0.9214
# Epoch 146/150
# 35/35 [==============================] - 19s 535ms/step - loss: 0.3827 - accuracy: 0.8761 - val_loss: 0.2709 - val_accuracy: 0.9248
# Epoch 147/150
# 35/35 [==============================] - 19s 537ms/step - loss: 0.3550 - accuracy: 0.8876 - val_loss: 0.2655 - val_accuracy: 0.9229
# Epoch 148/150
# 35/35 [==============================] - 19s 542ms/step - loss: 0.3824 - accuracy: 0.8796 - val_loss: 0.2736 - val_accuracy: 0.9199
# Epoch 149/150
# 35/35 [==============================] - 19s 536ms/step - loss: 0.3702 - accuracy: 0.8791 - val_loss: 0.2670 - val_accuracy: 0.9277
# Epoch 150/150
# 35/35 [==============================] - 19s 537ms/step - loss: 0.3727 - accuracy: 0.8802 - val_loss: 0.2612 - val_accuracy: 0.9229

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig(r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\src\visualization\VGG19\Accuracy_VGG19_1.png")

plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig(r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\src\visualization\VGG19\Loss_VGG19_1.png")

plt.show()

# %%
Path_model=r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\models\VGG19"
model.save(os.path.join(Path_model,"Amazigh_Handwritten_Recognition_VGG19_1.h5"))

# %%
from keras.models import load_model
#from sklearn.metrics import confusion_matrix
from mlxtend.evaluate import confusion_matrix


model = load_model(os.path.join(Path_model,"Amazigh_Handwritten_Recognition_VGG19_1.h5"))
# Predict the test data using the trained model
y_pred = model.predict(validation_generator)
# Out:
# 61/61 [==============================] - 24s 393ms/step

# %%
#Confution Matrix and Classification Report
target_names = ['ya', 'yab', 'yach', 'yad', 'yadd', 'yae', 'yaf', 'yag', 'yagh', 'yagw', 'yah', 'yahh', 'yaj',
                'yak', 'yakw', 'yal', 'yam', 'yan', 'yaq', 'yar', 'yarr', 'yas', 'yass', 'yat', 'yatt', 'yaw',
                'yax', 'yay', 'yaz', 'yazz', 'yey', 'yi', 'yu']
#print(classification_report(validation_generator.classes, y_pred, target_names=target_names))
y_pred = np.argmax(y_pred, axis=1)
print('Confusion Matrix')
conf_matrix=confusion_matrix(validation_generator.classes, y_pred)
print(conf_matrix)
# Out:
# Confusion Matrix
# [[244   0   0 ...   0   0   0]
#  [  0 210   0 ...   0   0   0]
#  [  0   0 214 ...   0   0   6]
#  ...
#  [  0   0   0 ... 202   0  14]
#  [  0   0   1 ...   0 201   0]
#  [  0   0   5 ...   6   0 221]]

# %%
from sklearn.metrics import classification_report

print('Classification Report')

print(classification_report(validation_generator.classes, y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#           ya       1.00      1.00      1.00       244
#          yab       1.00      0.92      0.96       228
#         yach       0.97      0.95      0.96       226
#          yad       0.99      0.99      0.99       238
#         yadd       0.86      0.87      0.86       245
#          yae       0.94      0.88      0.91       243
#          yaf       0.92      0.94      0.93       217
#          yag       0.96      0.81      0.88       221
#         yagh       0.89      0.95      0.91       237
#         yagw       0.84      0.92      0.88       240
#          yah       0.99      0.96      0.97       245
#         yahh       0.97      0.95      0.96       240
#          yaj       0.86      0.80      0.83       225
#          yak       0.94      0.82      0.88       227
#         yakw       0.75      0.98      0.85       244
#          yal       0.99      0.92      0.95       245
#          yam       0.97      0.81      0.88       254
#          yan       1.00      0.98      0.99       265
#          yaq       0.93      0.95      0.94       236
#          yar       0.98      0.94      0.96       243
#         yarr       0.92      0.97      0.94       228
#          yas       0.96      0.96      0.96       228
#         yass       0.87      0.97      0.92       237
#          yat       0.99      0.91      0.94       225
#         yatt       0.80      0.89      0.84       250
#          yaw       0.96      0.94      0.95       212
#          yax       1.00      0.93      0.96       222
#          yay       0.92      0.98      0.95       220
#          yaz       0.80      0.89      0.84       240
#         yazz       0.82      0.86      0.84       225
#          yey       0.96      0.94      0.95       216
#           yi       0.96      0.90      0.93       223
#           yu       0.91      0.95      0.93       233
#
#     accuracy                           0.92      7722
#    macro avg       0.93      0.92      0.92      7722
# weighted avg       0.93      0.92      0.92      7722

# %%
import matplotlib.pyplot as plt
import numpy as np
import itertools
def plot_confusion_matrix(cm, target_names, title='Confusion matrix', cmap=None, normalize=False):
    """
    arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions
    """
     
    if cmap is None:
        cmap = plt.get_cmap('YlGnBu')

    plt.figure(figsize=(20, 20))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    
    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylim(len(target_names)-0.5, -0.5)
    plt.ylabel('True labels')
    plt.xlabel('Predicted labels')
    #plt.savefig(r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\src\visualization\CNN\Loss_3.png")
    plt.savefig(r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\src\visualization\VGG19\Confusion_matrix_VGG19_1.png", dpi=500, bbox_inches = 'tight')
    plt.show()
    
plot_confusion_matrix(conf_matrix, target_names)
