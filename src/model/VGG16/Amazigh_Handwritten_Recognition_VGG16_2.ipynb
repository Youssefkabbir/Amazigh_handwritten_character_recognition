# %% [markdown]
# # The first step is to import the required Librairies

# %%
"""pandas is a Python package that provides fast, flexible, and expressive data structures
designed to make working with "relational" or "labeled" data both easy and intuitive."""
import pandas as pd
"""NumPy is a Python library used for working with arrays.
It also has functions for working in domain of linear algebra, fourier transform, and matrices."""
import numpy as np

"""Matplotlib is a comprehensive library for creating static, animated, and interactive
visualizations in Python. Matplotlib makes easy things easy and hard things possible."""
import  matplotlib.pyplot as plt 
"""OpenCV is the huge open-source library for the computer vision, machine learning, and image 
processing and now it plays a major role in real-time operation which is very important
in today’s systems"""
import cv2
"""This module provides a portable way of using operating system dependent functionality. If you
just want to read or write a file see open(), if you want to manipulate paths, see the os.path 
module, and if you want to read all the lines in all the files on the command line see the 
fileinput module"""
import os
"""The Python Imaging Library adds image processing capabilities to your Python interpreter.
This library provides extensive file format support, an efficient internal representation, 
and fairly powerful image processing capabilities."""
from PIL import Image
"""scikit-learn is a Python module for machine learning built on top of SciPy and is distributed
under the 3-Clause BSD license."""
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import itertools
"""Tensorflow is one of the most-used deep-learning frameworks. It’s arguably the most popular
machine learning platform on the web, with a broad range of users from those just starting out, 
to people looking for an edge in their careers and businesses. """
import tensorflow as tf 
from tensorflow.keras.utils import  to_categorical
from tensorflow.keras.models import Sequential ,load_model
from tensorflow.keras.layers import Conv2D,MaxPool2D,Dense ,Flatten,Dropout
print('the cell was executed without errors')
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16 
from tensorflow.keras.applications.vgg19 import   VGG19
#from keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras import layers, models, Model, optimizers
from tensorflow.keras.optimizers import RMSprop,SGD,Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
# Out:
# the cell was executed without errors

# %% [markdown]
# # We are going to load our Dataset

# %%
Path_Data=r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\data\processed"
Data=pd.read_csv(os.path.join(Path_Data,"Data.csv"))

# %%
data_path=r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\data\raw\AMHCD_64"
categories=os.listdir(data_path)
print(categories)
number_Classes=len(categories)
print(number_Classes)
# Out:
# ['ya', 'yab', 'yach', 'yad', 'yadd', 'yae', 'yaf', 'yag', 'yagh', 'yagw', 'yah', 'yahh', 'yaj', 'yak', 'yakw', 'yal', 'yam', 'yan', 'yaq', 'yar', 'yarr', 'yas', 'yass', 'yat', 'yatt', 'yaw', 'yax', 'yay', 'yaz', 'yazz', 'yey', 'yi', 'yu']
# 33

# %%
from sklearn.model_selection import train_test_split
Train, Validation = train_test_split(Data, test_size = 0.3, random_state = 20)


train_datagen = ImageDataGenerator( rescale=1./255)
print('the cell was executed without errors')
Train
# Out:
# the cell was executed without errors
#                                                     Path Classes
# 18692  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yat
# 22295  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yaz
# 18625  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yat
# 13017  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yam
# 8869   C:\Users\kabir\Desktop\Projects\Amazigh_handwr...    yahh
# ...                                                  ...     ...
# 14729  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yaq
# 23452  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yey
# 23775  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yey
# 4367   C:\Users\kabir\Desktop\Projects\Amazigh_handwr...     yae
# 15715  C:\Users\kabir\Desktop\Projects\Amazigh_handwr...    yarr
#
# [18018 rows x 2 columns]

# %%
train_generator=train_datagen.flow_from_dataframe(
dataframe=Train,
directory=data_path,
x_col='Path',
y_col='Classes',
batch_size=128,
seed=42,
shuffle=False,
class_mode="categorical",
#class_mode="sparse",

target_size=(64,64))
# Out:
# Found 18018 validated image filenames belonging to 33 classes.

# %%
validation_generator=train_datagen.flow_from_dataframe(
dataframe=Validation,
directory=data_path,
x_col='Path',
y_col='Classes',
batch_size=128,
seed=42,
shuffle=False,
class_mode="categorical",

#class_mode="sparse",
target_size=(64,64))

print('the cell was executed without errors')
# Out:
# Found 7722 validated image filenames belonging to 33 classes.
# the cell was executed without errors

# %%
img_input=(64, 64, 3)
vgg=VGG16(weights='imagenet', include_top=False,pooling='avg', input_shape=img_input)
for layer in vgg.layers:
    layer.trainable = False
x = vgg.output
x = Dense(64, activation="relu")(x)
x = Dropout(0.3)(x)
x = Flatten(name="flatten")(x)
x = Dense(2048, activation='relu')(x)
prd = Dense(number_Classes,activation='softmax')(x)
model = Model(inputs=vgg.input, outputs=prd)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 64, 64, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 64, 64, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 32, 32, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 32, 32, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 32, 32, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 16, 16, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 16, 16, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 16, 16, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 8, 8, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 8, 8, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 4, 4, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 2, 2, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 64)                32832
#
#  dropout (Dropout)           (None, 64)                0
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 2048)              133120
#
#  dense_2 (Dense)             (None, 33)                67617
#
# =================================================================
# Total params: 14,948,257
# Trainable params: 233,569
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
Path_Weights=r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\models\CNN"
#//checking checkpoint for selecting the best model for the emotion detection and save the best model with minimum validation loss having the name written on it in the current working folder
checkpoint = ModelCheckpoint("Weight_VGG16_2.h5",
                             save_weights_only=True,
                             monitor="val_loss",
                             mode="min",
                             save_best_only=True,
                             verbose=1)

#//reduce_lr will also monitor the validation loss 
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              mode="min",
                              factor=0.1,
                              patience=2,
                              verbose=1,
                              min_lr=.000001)
#callb = [earlystop, checkpoint, reduce_lr]

call=[ checkpoint,reduce_lr]

# %%
adam = Adam(learning_rate=.0001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
s=train_generator.n/16
print(s)
# Out:
# 1126.125

# %%
batch_size=512
#//This last block of codes will train our codes with the given parameters where it will fit train generator for training epochs to 25, callbacks will call the earlystop, checkpoint and reduce_lr and validation data will be equal to validation generator which was created on the first execution 
history = model.fit_generator(generator=train_generator,steps_per_epoch=train_generator.n/batch_size, epochs=200
                              ,validation_data=validation_generator,validation_steps=validation_generator.n/batch_size)
# Out:
# Epoch 1/200
# C:\Users\kabir\AppData\Local\Temp\ipykernel_3688\1632587513.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(generator=train_generator,steps_per_epoch=train_generator.n/batch_size, epochs=200
# 35/35 [==============================] - 7s 68ms/step - loss: 3.4278 - accuracy: 0.0833 - val_loss: 3.3077 - val_accuracy: 0.2402
# Epoch 2/200
# 35/35 [==============================] - 4s 61ms/step - loss: 3.1939 - accuracy: 0.2311 - val_loss: 2.9843 - val_accuracy: 0.4624
# Epoch 3/200
# 35/35 [==============================] - 2s 62ms/step - loss: 2.8337 - accuracy: 0.3571 - val_loss: 2.5297 - val_accuracy: 0.5444
# Epoch 4/200
# 35/35 [==============================] - 2s 65ms/step - loss: 2.4226 - accuracy: 0.4130 - val_loss: 2.0911 - val_accuracy: 0.6406
# Epoch 5/200
# 35/35 [==============================] - 2s 64ms/step - loss: 2.0646 - accuracy: 0.4941 - val_loss: 1.7351 - val_accuracy: 0.6953
# Epoch 6/200
# 35/35 [==============================] - 2s 63ms/step - loss: 1.7759 - accuracy: 0.5293 - val_loss: 1.4538 - val_accuracy: 0.7715
# Epoch 7/200
# 35/35 [==============================] - 2s 64ms/step - loss: 1.5534 - accuracy: 0.5781 - val_loss: 1.2297 - val_accuracy: 0.8101
# Epoch 8/200
# 35/35 [==============================] - 2s 64ms/step - loss: 1.3750 - accuracy: 0.6341 - val_loss: 1.0643 - val_accuracy: 0.8135
# Epoch 9/200
# 35/35 [==============================] - 2s 64ms/step - loss: 1.2390 - accuracy: 0.6446 - val_loss: 0.9376 - val_accuracy: 0.8477
# Epoch 10/200
# 35/35 [==============================] - 2s 68ms/step - loss: 1.1130 - accuracy: 0.6931 - val_loss: 0.8317 - val_accuracy: 0.8647
# Epoch 11/200
# 35/35 [==============================] - 2s 68ms/step - loss: 1.0205 - accuracy: 0.7116 - val_loss: 0.7584 - val_accuracy: 0.8594
# Epoch 12/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.9682 - accuracy: 0.7244 - val_loss: 0.6939 - val_accuracy: 0.8794
# Epoch 13/200
# 35/35 [==============================] - 2s 64ms/step - loss: 0.9113 - accuracy: 0.7394 - val_loss: 0.6351 - val_accuracy: 0.8872
# Epoch 14/200
# 35/35 [==============================] - 2s 64ms/step - loss: 0.8334 - accuracy: 0.7702 - val_loss: 0.5951 - val_accuracy: 0.8901
# Epoch 15/200
# 35/35 [==============================] - 2s 64ms/step - loss: 0.7898 - accuracy: 0.7820 - val_loss: 0.5509 - val_accuracy: 0.8882
# Epoch 16/200
# 35/35 [==============================] - 2s 62ms/step - loss: 0.7453 - accuracy: 0.7862 - val_loss: 0.5201 - val_accuracy: 0.8984
# Epoch 17/200
# 35/35 [==============================] - 3s 81ms/step - loss: 0.7140 - accuracy: 0.7964 - val_loss: 0.4875 - val_accuracy: 0.8955
# Epoch 18/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.6747 - accuracy: 0.8066 - val_loss: 0.4585 - val_accuracy: 0.9077
# Epoch 19/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.6269 - accuracy: 0.8242 - val_loss: 0.4386 - val_accuracy: 0.9072
# Epoch 20/200
# 35/35 [==============================] - 3s 84ms/step - loss: 0.6103 - accuracy: 0.8215 - val_loss: 0.4167 - val_accuracy: 0.9062
# Epoch 21/200
# 35/35 [==============================] - 3s 79ms/step - loss: 0.5919 - accuracy: 0.8272 - val_loss: 0.3982 - val_accuracy: 0.9102
# Epoch 22/200
# 35/35 [==============================] - 2s 62ms/step - loss: 0.5751 - accuracy: 0.8346 - val_loss: 0.3795 - val_accuracy: 0.9146
# Epoch 23/200
# 35/35 [==============================] - 2s 63ms/step - loss: 0.5373 - accuracy: 0.8475 - val_loss: 0.3659 - val_accuracy: 0.9155
# Epoch 24/200
# 35/35 [==============================] - 2s 65ms/step - loss: 0.5283 - accuracy: 0.8440 - val_loss: 0.3498 - val_accuracy: 0.9155
# Epoch 25/200
# 35/35 [==============================] - 2s 62ms/step - loss: 0.5079 - accuracy: 0.8490 - val_loss: 0.3412 - val_accuracy: 0.9219
# Epoch 26/200
# 35/35 [==============================] - 2s 62ms/step - loss: 0.4801 - accuracy: 0.8609 - val_loss: 0.3220 - val_accuracy: 0.9233
# Epoch 27/200
# 35/35 [==============================] - 2s 62ms/step - loss: 0.4718 - accuracy: 0.8626 - val_loss: 0.3105 - val_accuracy: 0.9258
# Epoch 28/200
# 35/35 [==============================] - 2s 61ms/step - loss: 0.4677 - accuracy: 0.8583 - val_loss: 0.3021 - val_accuracy: 0.9209
# Epoch 29/200
# 35/35 [==============================] - 2s 63ms/step - loss: 0.4535 - accuracy: 0.8655 - val_loss: 0.2928 - val_accuracy: 0.9326
# Epoch 30/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.4232 - accuracy: 0.8789 - val_loss: 0.2803 - val_accuracy: 0.9326
# Epoch 31/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.4220 - accuracy: 0.8691 - val_loss: 0.2717 - val_accuracy: 0.9307
# Epoch 32/200
# 35/35 [==============================] - 2s 64ms/step - loss: 0.4338 - accuracy: 0.8728 - val_loss: 0.2688 - val_accuracy: 0.9307
# Epoch 33/200
# 35/35 [==============================] - 2s 65ms/step - loss: 0.4193 - accuracy: 0.8776 - val_loss: 0.2667 - val_accuracy: 0.9380
# Epoch 34/200
# 35/35 [==============================] - 2s 64ms/step - loss: 0.3995 - accuracy: 0.8856 - val_loss: 0.2514 - val_accuracy: 0.9385
# Epoch 35/200
# 35/35 [==============================] - 2s 63ms/step - loss: 0.3736 - accuracy: 0.8928 - val_loss: 0.2430 - val_accuracy: 0.9385
# Epoch 36/200
# 35/35 [==============================] - 2s 63ms/step - loss: 0.3830 - accuracy: 0.8874 - val_loss: 0.2394 - val_accuracy: 0.9370
# Epoch 37/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.3634 - accuracy: 0.8943 - val_loss: 0.2389 - val_accuracy: 0.9346
# Epoch 38/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.3702 - accuracy: 0.8861 - val_loss: 0.2245 - val_accuracy: 0.9404
# Epoch 39/200
# 35/35 [==============================] - 2s 65ms/step - loss: 0.3393 - accuracy: 0.9010 - val_loss: 0.2236 - val_accuracy: 0.9404
# Epoch 40/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.3460 - accuracy: 0.8965 - val_loss: 0.2193 - val_accuracy: 0.9434
# Epoch 41/200
# 35/35 [==============================] - 2s 64ms/step - loss: 0.3468 - accuracy: 0.8987 - val_loss: 0.2181 - val_accuracy: 0.9404
# Epoch 42/200
# 35/35 [==============================] - 2s 65ms/step - loss: 0.3363 - accuracy: 0.9000 - val_loss: 0.2081 - val_accuracy: 0.9463
# Epoch 43/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.3366 - accuracy: 0.9028 - val_loss: 0.2081 - val_accuracy: 0.9468
# Epoch 44/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.3182 - accuracy: 0.9023 - val_loss: 0.2060 - val_accuracy: 0.9443
# Epoch 45/200
# 35/35 [==============================] - 2s 65ms/step - loss: 0.3106 - accuracy: 0.9083 - val_loss: 0.1987 - val_accuracy: 0.9473
# Epoch 46/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.3164 - accuracy: 0.9065 - val_loss: 0.1926 - val_accuracy: 0.9478
# Epoch 47/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.2968 - accuracy: 0.9120 - val_loss: 0.1931 - val_accuracy: 0.9497
# Epoch 48/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.2934 - accuracy: 0.9093 - val_loss: 0.1894 - val_accuracy: 0.9497
# Epoch 49/200
# 35/35 [==============================] - 2s 65ms/step - loss: 0.2970 - accuracy: 0.9074 - val_loss: 0.1859 - val_accuracy: 0.9521
# Epoch 50/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.3052 - accuracy: 0.9052 - val_loss: 0.1857 - val_accuracy: 0.9517
# Epoch 51/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.2907 - accuracy: 0.9151 - val_loss: 0.1792 - val_accuracy: 0.9517
# Epoch 52/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.2880 - accuracy: 0.9128 - val_loss: 0.1755 - val_accuracy: 0.9517
# Epoch 53/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.2841 - accuracy: 0.9085 - val_loss: 0.1722 - val_accuracy: 0.9551
# Epoch 54/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.2681 - accuracy: 0.9225 - val_loss: 0.1700 - val_accuracy: 0.9551
# Epoch 55/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.2697 - accuracy: 0.9182 - val_loss: 0.1670 - val_accuracy: 0.9536
# Epoch 56/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.2772 - accuracy: 0.9184 - val_loss: 0.1662 - val_accuracy: 0.9556
# Epoch 57/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.2574 - accuracy: 0.9236 - val_loss: 0.1633 - val_accuracy: 0.9556
# Epoch 58/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.2706 - accuracy: 0.9138 - val_loss: 0.1579 - val_accuracy: 0.9565
# Epoch 59/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.2601 - accuracy: 0.9238 - val_loss: 0.1563 - val_accuracy: 0.9595
# Epoch 60/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.2611 - accuracy: 0.9222 - val_loss: 0.1561 - val_accuracy: 0.9570
# Epoch 61/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.2460 - accuracy: 0.9217 - val_loss: 0.1543 - val_accuracy: 0.9536
# Epoch 62/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.2339 - accuracy: 0.9358 - val_loss: 0.1518 - val_accuracy: 0.9580
# Epoch 63/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.2364 - accuracy: 0.9312 - val_loss: 0.1501 - val_accuracy: 0.9590
# Epoch 64/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.2451 - accuracy: 0.9258 - val_loss: 0.1509 - val_accuracy: 0.9536
# Epoch 65/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.2382 - accuracy: 0.9282 - val_loss: 0.1457 - val_accuracy: 0.9551
# Epoch 66/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.2351 - accuracy: 0.9297 - val_loss: 0.1402 - val_accuracy: 0.9585
# Epoch 67/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.2313 - accuracy: 0.9294 - val_loss: 0.1468 - val_accuracy: 0.9561
# Epoch 68/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.2327 - accuracy: 0.9251 - val_loss: 0.1440 - val_accuracy: 0.9585
# Epoch 69/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.2226 - accuracy: 0.9360 - val_loss: 0.1412 - val_accuracy: 0.9595
# Epoch 70/200
# 35/35 [==============================] - 2s 66ms/step - loss: 0.2328 - accuracy: 0.9314 - val_loss: 0.1416 - val_accuracy: 0.9590
# Epoch 71/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.2161 - accuracy: 0.9340 - val_loss: 0.1373 - val_accuracy: 0.9600
# Epoch 72/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.2198 - accuracy: 0.9319 - val_loss: 0.1379 - val_accuracy: 0.9609
# Epoch 73/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.2138 - accuracy: 0.9373 - val_loss: 0.1318 - val_accuracy: 0.9609
# Epoch 74/200
# 35/35 [==============================] - 3s 71ms/step - loss: 0.2080 - accuracy: 0.9392 - val_loss: 0.1320 - val_accuracy: 0.9639
# Epoch 75/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.2151 - accuracy: 0.9362 - val_loss: 0.1357 - val_accuracy: 0.9595
# Epoch 76/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.1973 - accuracy: 0.9416 - val_loss: 0.1292 - val_accuracy: 0.9619
# Epoch 77/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.1976 - accuracy: 0.9395 - val_loss: 0.1309 - val_accuracy: 0.9590
# Epoch 78/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.2099 - accuracy: 0.9323 - val_loss: 0.1332 - val_accuracy: 0.9575
# Epoch 79/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.2083 - accuracy: 0.9340 - val_loss: 0.1286 - val_accuracy: 0.9629
# Epoch 80/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.2037 - accuracy: 0.9353 - val_loss: 0.1236 - val_accuracy: 0.9634
# Epoch 81/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.1969 - accuracy: 0.9399 - val_loss: 0.1247 - val_accuracy: 0.9629
# Epoch 82/200
# 35/35 [==============================] - 3s 71ms/step - loss: 0.1928 - accuracy: 0.9440 - val_loss: 0.1228 - val_accuracy: 0.9614
# Epoch 83/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.1947 - accuracy: 0.9418 - val_loss: 0.1192 - val_accuracy: 0.9663
# Epoch 84/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.1904 - accuracy: 0.9410 - val_loss: 0.1237 - val_accuracy: 0.9624
# Epoch 85/200
# 35/35 [==============================] - 2s 67ms/step - loss: 0.1790 - accuracy: 0.9441 - val_loss: 0.1201 - val_accuracy: 0.9619
# Epoch 86/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.1907 - accuracy: 0.9425 - val_loss: 0.1183 - val_accuracy: 0.9639
# Epoch 87/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.1896 - accuracy: 0.9405 - val_loss: 0.1154 - val_accuracy: 0.9653
# Epoch 88/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.1889 - accuracy: 0.9421 - val_loss: 0.1195 - val_accuracy: 0.9639
# Epoch 89/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.1882 - accuracy: 0.9462 - val_loss: 0.1143 - val_accuracy: 0.9668
# Epoch 90/200
# 35/35 [==============================] - 3s 71ms/step - loss: 0.1836 - accuracy: 0.9468 - val_loss: 0.1149 - val_accuracy: 0.9639
# Epoch 91/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.1745 - accuracy: 0.9468 - val_loss: 0.1123 - val_accuracy: 0.9678
# Epoch 92/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.1881 - accuracy: 0.9395 - val_loss: 0.1155 - val_accuracy: 0.9678
# Epoch 93/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.1802 - accuracy: 0.9486 - val_loss: 0.1107 - val_accuracy: 0.9663
# Epoch 94/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.1837 - accuracy: 0.9445 - val_loss: 0.1104 - val_accuracy: 0.9648
# Epoch 95/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.1754 - accuracy: 0.9470 - val_loss: 0.1126 - val_accuracy: 0.9658
# Epoch 96/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.1758 - accuracy: 0.9423 - val_loss: 0.1087 - val_accuracy: 0.9658
# Epoch 97/200
# 35/35 [==============================] - 2s 71ms/step - loss: 0.1749 - accuracy: 0.9475 - val_loss: 0.1097 - val_accuracy: 0.9653
# Epoch 98/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.1658 - accuracy: 0.9473 - val_loss: 0.1070 - val_accuracy: 0.9663
# Epoch 99/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.1790 - accuracy: 0.9423 - val_loss: 0.1099 - val_accuracy: 0.9668
# Epoch 100/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.1748 - accuracy: 0.9450 - val_loss: 0.1076 - val_accuracy: 0.9678
# Epoch 101/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.1684 - accuracy: 0.9477 - val_loss: 0.1110 - val_accuracy: 0.9639
# Epoch 102/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.1658 - accuracy: 0.9500 - val_loss: 0.1077 - val_accuracy: 0.9678
# Epoch 103/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.1575 - accuracy: 0.9504 - val_loss: 0.1024 - val_accuracy: 0.9697
# Epoch 104/200
# 35/35 [==============================] - 3s 71ms/step - loss: 0.1637 - accuracy: 0.9501 - val_loss: 0.1039 - val_accuracy: 0.9688
# Epoch 105/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.1601 - accuracy: 0.9501 - val_loss: 0.1035 - val_accuracy: 0.9653
# Epoch 106/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.1683 - accuracy: 0.9460 - val_loss: 0.1033 - val_accuracy: 0.9668
# Epoch 107/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.1658 - accuracy: 0.9489 - val_loss: 0.0994 - val_accuracy: 0.9678
# Epoch 108/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.1587 - accuracy: 0.9503 - val_loss: 0.0991 - val_accuracy: 0.9707
# Epoch 109/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.1509 - accuracy: 0.9502 - val_loss: 0.1010 - val_accuracy: 0.9683
# Epoch 110/200
# 35/35 [==============================] - 3s 71ms/step - loss: 0.1646 - accuracy: 0.9470 - val_loss: 0.0985 - val_accuracy: 0.9712
# Epoch 111/200
# 35/35 [==============================] - 3s 71ms/step - loss: 0.1594 - accuracy: 0.9523 - val_loss: 0.1006 - val_accuracy: 0.9683
# Epoch 112/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.1626 - accuracy: 0.9466 - val_loss: 0.0972 - val_accuracy: 0.9697
# Epoch 113/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.1563 - accuracy: 0.9484 - val_loss: 0.0976 - val_accuracy: 0.9692
# Epoch 114/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.1442 - accuracy: 0.9577 - val_loss: 0.0973 - val_accuracy: 0.9692
# Epoch 115/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.1462 - accuracy: 0.9544 - val_loss: 0.0969 - val_accuracy: 0.9707
# Epoch 116/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.1460 - accuracy: 0.9538 - val_loss: 0.0959 - val_accuracy: 0.9683
# Epoch 117/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.1532 - accuracy: 0.9551 - val_loss: 0.0937 - val_accuracy: 0.9717
# Epoch 118/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.1423 - accuracy: 0.9542 - val_loss: 0.0966 - val_accuracy: 0.9678
# Epoch 119/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.1400 - accuracy: 0.9589 - val_loss: 0.0951 - val_accuracy: 0.9712
# Epoch 120/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.1527 - accuracy: 0.9516 - val_loss: 0.0956 - val_accuracy: 0.9697
# Epoch 121/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.1444 - accuracy: 0.9557 - val_loss: 0.0937 - val_accuracy: 0.9717
# Epoch 122/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.1444 - accuracy: 0.9544 - val_loss: 0.0968 - val_accuracy: 0.9678
# Epoch 123/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.1493 - accuracy: 0.9546 - val_loss: 0.0928 - val_accuracy: 0.9741
# Epoch 124/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.1403 - accuracy: 0.9546 - val_loss: 0.0923 - val_accuracy: 0.9712
# Epoch 125/200
# 35/35 [==============================] - 2s 68ms/step - loss: 0.1386 - accuracy: 0.9579 - val_loss: 0.0909 - val_accuracy: 0.9707
# Epoch 126/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.1397 - accuracy: 0.9551 - val_loss: 0.0910 - val_accuracy: 0.9717
# Epoch 127/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.1422 - accuracy: 0.9567 - val_loss: 0.0889 - val_accuracy: 0.9707
# Epoch 128/200
# 35/35 [==============================] - 3s 71ms/step - loss: 0.1533 - accuracy: 0.9490 - val_loss: 0.0898 - val_accuracy: 0.9717
# Epoch 129/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.1343 - accuracy: 0.9581 - val_loss: 0.0884 - val_accuracy: 0.9731
# Epoch 130/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.1428 - accuracy: 0.9542 - val_loss: 0.0923 - val_accuracy: 0.9712
# Epoch 131/200
# 35/35 [==============================] - 3s 71ms/step - loss: 0.1316 - accuracy: 0.9583 - val_loss: 0.0897 - val_accuracy: 0.9727
# Epoch 132/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.1434 - accuracy: 0.9546 - val_loss: 0.0888 - val_accuracy: 0.9751
# Epoch 133/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.1342 - accuracy: 0.9568 - val_loss: 0.0898 - val_accuracy: 0.9736
# Epoch 134/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.1328 - accuracy: 0.9603 - val_loss: 0.0871 - val_accuracy: 0.9746
# Epoch 135/200
# 35/35 [==============================] - 3s 74ms/step - loss: 0.1418 - accuracy: 0.9533 - val_loss: 0.0870 - val_accuracy: 0.9746
# Epoch 136/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.1320 - accuracy: 0.9609 - val_loss: 0.0852 - val_accuracy: 0.9746
# Epoch 137/200
# 35/35 [==============================] - 3s 70ms/step - loss: 0.1240 - accuracy: 0.9611 - val_loss: 0.0867 - val_accuracy: 0.9751
# Epoch 138/200
# 35/35 [==============================] - 2s 69ms/step - loss: 0.1290 - accuracy: 0.9626 - val_loss: 0.0860 - val_accuracy: 0.9736
# Epoch 139/200
# 35/35 [==============================] - 3s 71ms/step - loss: 0.1299 - accuracy: 0.9605 - val_loss: 0.0863 - val_accuracy: 0.9731
# Epoch 140/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.1307 - accuracy: 0.9575 - val_loss: 0.0822 - val_accuracy: 0.9766
# Epoch 141/200
# 35/35 [==============================] - 3s 71ms/step - loss: 0.1229 - accuracy: 0.9600 - val_loss: 0.0860 - val_accuracy: 0.9731
# Epoch 142/200
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1281 - accuracy: 0.9605 - val_loss: 0.0901 - val_accuracy: 0.9741
# Epoch 143/200
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1200 - accuracy: 0.9622 - val_loss: 0.0837 - val_accuracy: 0.9746
# Epoch 144/200
# 35/35 [==============================] - 3s 71ms/step - loss: 0.1252 - accuracy: 0.9590 - val_loss: 0.0855 - val_accuracy: 0.9717
# Epoch 145/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.1252 - accuracy: 0.9609 - val_loss: 0.0818 - val_accuracy: 0.9741
# Epoch 146/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.1274 - accuracy: 0.9611 - val_loss: 0.0813 - val_accuracy: 0.9751
# Epoch 147/200
# 35/35 [==============================] - 2s 70ms/step - loss: 0.1177 - accuracy: 0.9637 - val_loss: 0.0834 - val_accuracy: 0.9741
# Epoch 148/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.1225 - accuracy: 0.9609 - val_loss: 0.0826 - val_accuracy: 0.9722
# Epoch 149/200
# 35/35 [==============================] - 3s 71ms/step - loss: 0.1251 - accuracy: 0.9583 - val_loss: 0.0816 - val_accuracy: 0.9746
# Epoch 150/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.1202 - accuracy: 0.9614 - val_loss: 0.0783 - val_accuracy: 0.9751
# Epoch 151/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.1107 - accuracy: 0.9631 - val_loss: 0.0809 - val_accuracy: 0.9761
# Epoch 152/200
# 35/35 [==============================] - 3s 82ms/step - loss: 0.1199 - accuracy: 0.9594 - val_loss: 0.0789 - val_accuracy: 0.9741
# Epoch 153/200
# 35/35 [==============================] - 3s 88ms/step - loss: 0.1288 - accuracy: 0.9614 - val_loss: 0.0783 - val_accuracy: 0.9766
# Epoch 154/200
# 35/35 [==============================] - 3s 76ms/step - loss: 0.1196 - accuracy: 0.9590 - val_loss: 0.0779 - val_accuracy: 0.9731
# Epoch 155/200
# 35/35 [==============================] - 3s 74ms/step - loss: 0.1133 - accuracy: 0.9648 - val_loss: 0.0804 - val_accuracy: 0.9736
# Epoch 156/200
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1259 - accuracy: 0.9599 - val_loss: 0.0802 - val_accuracy: 0.9756
# Epoch 157/200
# 35/35 [==============================] - 3s 77ms/step - loss: 0.1210 - accuracy: 0.9638 - val_loss: 0.0822 - val_accuracy: 0.9751
# Epoch 158/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.1158 - accuracy: 0.9625 - val_loss: 0.0786 - val_accuracy: 0.9751
# Epoch 159/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.1242 - accuracy: 0.9618 - val_loss: 0.0770 - val_accuracy: 0.9766
# Epoch 160/200
# 35/35 [==============================] - 3s 76ms/step - loss: 0.1142 - accuracy: 0.9646 - val_loss: 0.0763 - val_accuracy: 0.9751
# Epoch 161/200
# 35/35 [==============================] - 3s 76ms/step - loss: 0.1109 - accuracy: 0.9648 - val_loss: 0.0760 - val_accuracy: 0.9751
# Epoch 162/200
# 35/35 [==============================] - 3s 71ms/step - loss: 0.1214 - accuracy: 0.9616 - val_loss: 0.0775 - val_accuracy: 0.9746
# Epoch 163/200
# 35/35 [==============================] - 3s 70ms/step - loss: 0.1111 - accuracy: 0.9670 - val_loss: 0.0740 - val_accuracy: 0.9785
# Epoch 164/200
# 35/35 [==============================] - 3s 85ms/step - loss: 0.1138 - accuracy: 0.9631 - val_loss: 0.0772 - val_accuracy: 0.9736
# Epoch 165/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.1196 - accuracy: 0.9661 - val_loss: 0.0739 - val_accuracy: 0.9775
# Epoch 166/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.1186 - accuracy: 0.9592 - val_loss: 0.0737 - val_accuracy: 0.9780
# Epoch 167/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.1037 - accuracy: 0.9688 - val_loss: 0.0749 - val_accuracy: 0.9761
# Epoch 168/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.1012 - accuracy: 0.9674 - val_loss: 0.0773 - val_accuracy: 0.9751
# Epoch 169/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.1133 - accuracy: 0.9651 - val_loss: 0.0742 - val_accuracy: 0.9746
# Epoch 170/200
# 35/35 [==============================] - 3s 71ms/step - loss: 0.1044 - accuracy: 0.9653 - val_loss: 0.0725 - val_accuracy: 0.9785
# Epoch 171/200
# 35/35 [==============================] - 3s 71ms/step - loss: 0.1036 - accuracy: 0.9653 - val_loss: 0.0751 - val_accuracy: 0.9756
# Epoch 172/200
# 35/35 [==============================] - 3s 76ms/step - loss: 0.1068 - accuracy: 0.9688 - val_loss: 0.0745 - val_accuracy: 0.9780
# Epoch 173/200
# 35/35 [==============================] - 3s 71ms/step - loss: 0.1115 - accuracy: 0.9679 - val_loss: 0.0763 - val_accuracy: 0.9766
# Epoch 174/200
# 35/35 [==============================] - 3s 71ms/step - loss: 0.1102 - accuracy: 0.9635 - val_loss: 0.0715 - val_accuracy: 0.9780
# Epoch 175/200
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1052 - accuracy: 0.9672 - val_loss: 0.0732 - val_accuracy: 0.9766
# Epoch 176/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.1069 - accuracy: 0.9664 - val_loss: 0.0727 - val_accuracy: 0.9766
# Epoch 177/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.1083 - accuracy: 0.9659 - val_loss: 0.0729 - val_accuracy: 0.9775
# Epoch 178/200
# 35/35 [==============================] - 3s 78ms/step - loss: 0.0978 - accuracy: 0.9716 - val_loss: 0.0726 - val_accuracy: 0.9780
# Epoch 179/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.1159 - accuracy: 0.9651 - val_loss: 0.0714 - val_accuracy: 0.9756
# Epoch 180/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.1110 - accuracy: 0.9646 - val_loss: 0.0732 - val_accuracy: 0.9766
# Epoch 181/200
# 35/35 [==============================] - 3s 79ms/step - loss: 0.1090 - accuracy: 0.9657 - val_loss: 0.0718 - val_accuracy: 0.9785
# Epoch 182/200
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1072 - accuracy: 0.9653 - val_loss: 0.0713 - val_accuracy: 0.9785
# Epoch 183/200
# 35/35 [==============================] - 3s 80ms/step - loss: 0.1015 - accuracy: 0.9668 - val_loss: 0.0715 - val_accuracy: 0.9771
# Epoch 184/200
# 35/35 [==============================] - 3s 74ms/step - loss: 0.0991 - accuracy: 0.9703 - val_loss: 0.0704 - val_accuracy: 0.9780
# Epoch 185/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.1028 - accuracy: 0.9657 - val_loss: 0.0704 - val_accuracy: 0.9790
# Epoch 186/200
# 35/35 [==============================] - 3s 76ms/step - loss: 0.1008 - accuracy: 0.9664 - val_loss: 0.0694 - val_accuracy: 0.9766
# Epoch 187/200
# 35/35 [==============================] - 3s 78ms/step - loss: 0.1002 - accuracy: 0.9672 - val_loss: 0.0710 - val_accuracy: 0.9766
# Epoch 188/200
# 35/35 [==============================] - 3s 71ms/step - loss: 0.0994 - accuracy: 0.9659 - val_loss: 0.0709 - val_accuracy: 0.9780
# Epoch 189/200
# 35/35 [==============================] - 3s 71ms/step - loss: 0.1033 - accuracy: 0.9712 - val_loss: 0.0734 - val_accuracy: 0.9775
# Epoch 190/200
# 35/35 [==============================] - 3s 92ms/step - loss: 0.1021 - accuracy: 0.9698 - val_loss: 0.0685 - val_accuracy: 0.9780
# Epoch 191/200
# 35/35 [==============================] - 3s 74ms/step - loss: 0.0959 - accuracy: 0.9685 - val_loss: 0.0717 - val_accuracy: 0.9766
# Epoch 192/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.0979 - accuracy: 0.9707 - val_loss: 0.0686 - val_accuracy: 0.9790
# Epoch 193/200
# 35/35 [==============================] - 3s 71ms/step - loss: 0.0962 - accuracy: 0.9688 - val_loss: 0.0670 - val_accuracy: 0.9780
# Epoch 194/200
# 35/35 [==============================] - 3s 82ms/step - loss: 0.0900 - accuracy: 0.9750 - val_loss: 0.0674 - val_accuracy: 0.9790
# Epoch 195/200
# 35/35 [==============================] - 3s 81ms/step - loss: 0.1048 - accuracy: 0.9666 - val_loss: 0.0684 - val_accuracy: 0.9785
# Epoch 196/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.1017 - accuracy: 0.9692 - val_loss: 0.0677 - val_accuracy: 0.9761
# Epoch 197/200
# 35/35 [==============================] - 3s 74ms/step - loss: 0.0963 - accuracy: 0.9694 - val_loss: 0.0710 - val_accuracy: 0.9771
# Epoch 198/200
# 35/35 [==============================] - 3s 73ms/step - loss: 0.0990 - accuracy: 0.9705 - val_loss: 0.0699 - val_accuracy: 0.9785
# Epoch 199/200
# 35/35 [==============================] - 3s 72ms/step - loss: 0.0947 - accuracy: 0.9692 - val_loss: 0.0700 - val_accuracy: 0.9766
# Epoch 200/200
# 35/35 [==============================] - 3s 74ms/step - loss: 0.0876 - accuracy: 0.9720 - val_loss: 0.0678 - val_accuracy: 0.9780

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig(r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\src\visualization\VGG16\Accuracy_VGG16_1.png")

plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.savefig(r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\src\visualization\VGG16\Loss_VGG16_1.png")

plt.show()

# %%
Path_model=r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\models\VGG16"
model.save(os.path.join(Path_model,"Amazigh_Handwritten_Recognition_VGG16_2.h5"))

# %%
from keras.models import load_model
#from sklearn.metrics import confusion_matrix


model = load_model(os.path.join(Path_model,"Amazigh_Handwritten_Recognition_VGG16_2.h5"))

# %%
# Predict the test data using the trained model
y_pred = model.predict(validation_generator)
# Out:
# 61/61 [==============================] - 4s 62ms/step

# %%
from mlxtend.evaluate import confusion_matrix

#Confution Matrix and Classification Report
target_names = ['ya', 'yab', 'yach', 'yad', 'yadd', 'yae', 'yaf', 'yag', 'yagh', 'yagw', 'yah', 'yahh', 'yaj',
                'yak', 'yakw', 'yal', 'yam', 'yan', 'yaq', 'yar', 'yarr', 'yas', 'yass', 'yat', 'yatt', 'yaw',
                'yax', 'yay', 'yaz', 'yazz', 'yey', 'yi', 'yu']
#print(classification_report(validation_generator.classes, y_pred, target_names=target_names))
y_pred = np.argmax(y_pred, axis=1)
print('Confusion Matrix')
conf_matrix=confusion_matrix(validation_generator.classes, y_pred)
print(conf_matrix)
# Out:
# Confusion Matrix
# [[244   0   0 ...   0   0   0]
#  [  0 226   0 ...   0   0   0]
#  [  0   1 224 ...   0   0   1]
#  ...
#  [  0   0   0 ... 213   0   3]
#  [  0   0   0 ...   1 216   0]
#  [  0   0   1 ...   3   0 229]]

# %%
from sklearn.metrics import classification_report

print('Classification Report')

print(classification_report(validation_generator.classes, y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#           ya       1.00      1.00      1.00       244
#          yab       1.00      0.99      0.99       228
#         yach       0.99      0.99      0.99       226
#          yad       0.98      0.99      0.98       238
#         yadd       0.96      0.96      0.96       245
#          yae       1.00      0.99      1.00       243
#          yaf       0.98      0.99      0.98       217
#          yag       0.99      0.99      0.99       221
#         yagh       0.98      0.98      0.98       237
#         yagw       0.98      0.96      0.97       240
#          yah       0.99      0.99      0.99       245
#         yahh       0.98      0.97      0.98       240
#          yaj       0.99      0.99      0.99       225
#          yak       0.99      0.96      0.98       227
#         yakw       0.96      0.99      0.97       244
#          yal       0.98      0.98      0.98       245
#          yam       0.98      0.99      0.98       254
#          yan       1.00      1.00      1.00       265
#          yaq       0.98      0.99      0.99       236
#          yar       0.98      0.99      0.98       243
#         yarr       0.98      0.96      0.97       228
#          yas       0.99      0.97      0.98       228
#         yass       0.95      0.98      0.97       237
#          yat       1.00      0.99      1.00       225
#         yatt       0.98      0.96      0.97       250
#          yaw       1.00      0.99      0.99       212
#          yax       0.99      0.99      0.99       222
#          yay       0.97      0.99      0.98       220
#          yaz       0.92      0.92      0.92       240
#         yazz       0.92      0.92      0.92       225
#          yey       0.98      0.99      0.98       216
#           yi       0.99      0.97      0.98       223
#           yu       0.98      0.98      0.98       233
#
#     accuracy                           0.98      7722
#    macro avg       0.98      0.98      0.98      7722
# weighted avg       0.98      0.98      0.98      7722

# %%
import matplotlib.pyplot as plt
import numpy as np
import itertools
def plot_confusion_matrix(cm, target_names, title='Confusion matrix', cmap=None, normalize=False):
    """
    arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions
    """
     
    if cmap is None:
        cmap = plt.get_cmap('YlGnBu')

    plt.figure(figsize=(20, 20))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    
    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylim(len(target_names)-0.5, -0.5)
    plt.ylabel('True labels')
    plt.xlabel('Predicted labels')
    #plt.savefig(r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\src\visualization\CNN\Loss_3.png")
    plt.savefig(r"C:\Users\kabir\Desktop\Projects\Amazigh_handwritten_character_recognition\src\visualization\VGG16\Confusion_matrix_VGG16_2.png", dpi=500, bbox_inches = 'tight')
    plt.show()
    
plot_confusion_matrix(conf_matrix, target_names)
